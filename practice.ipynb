# %%
import os
import xml.etree.ElementTree as ET
import csv
import json

# Define the absolute path of the CSV file
csv_dir = os.path.abspath('user_data_23_4.csv')

# Open the CSV file in read mode
with open(csv_dir, 'r') as file:
    
    # Create a CSV reader object
    reader = csv.reader(file)
    
    # Iterate through each row in the CSV file
    for row in reader:
        # Each row is a list containing the values of the CSV columns
        # Print the values of the current row
        print(row)
# Out:
# ['First Name', 'Second Name', 'Age (Years)', 'Sex', 'Vehicle Make', 'Vehicle Model', 'Vehicle Year', 'Vehicle Type']
# ['Leon', 'Smith', '48', 'Male', 'Mercedes-Benz', 'Astro Cargo', '2009', 'Pickup']
# ['Margaret', 'Mason', '35', 'Female', 'Honda', 'Sable', '2015', 'Van/Minivan']
# ['Guy', 'Harrison', '26', 'Male', 'Chevrolet', 'S60', '2013', 'SUV']
# ['Denise', 'Robinson', '30', 'Female', 'Ford', 'Tucson', '2002', 'Sedan']
# ['Simon', 'Fox', '27', 'Male', 'Toyota', 'Dart', '2005', 'SUV']
# ['Tom', 'Cooke', '69', 'Male', 'Hyundai', 'Liberty', '2019', 'Pickup']
# ['Fiona', 'Marshall', '86', 'Female', 'Chevrolet', 'Pathfinder', '2006', 'SUV']
# ['Mitchell', 'Davidson', '84', 'Male', 'Subaru', 'A8', '2006', 'Sedan, Hatchback, Wagon']
# ['Sam', 'Long', '83', 'Male', 'Mercedes-Benz', 'Azure T', '2018', 'Coupe']
# ['Sean', 'Perry', '87', 'Male', 'Ford', '1500 Regular Cab', '2010', 'SUV']
# ['Jacob', 'Bennett', '66', 'Male', 'Mercedes-Benz', 'Impreza', '1999', 'SUV']
# ['Lydia', 'Henderson', '62', 'Female', 'Nissan', 'GLC Coupe', '2006', 'SUV']
# ['Nathan', 'Slater', '81', 'Male', 'Cadillac', 'RLX', '1992', 'Sedan']
# ['Claire', 'Russell', '41', 'Female', 'Mercedes-Benz', 'Voyager', '1992', 'Van/Minivan']
# ['Katy', 'Green', '78', 'Female', 'Volvo', 'Galant', '1992', 'Wagon']
# ['Duncan', 'Moore', '67', 'Male', 'Volkswagen', 'SLK-Class', '1997', 'Sedan']
# ['Abbie', 'Miller', '73', 'Female', 'Dodge', 'del Sol', '2002', 'Sedan']
# ['Amber', 'Hobbs', '21', 'Female', 'Toyota', 'Rodeo', '1999', 'Van/Minivan']
# ['Samuel', 'Daniels', '47', 'Male', 'Volvo', 'Clarity Electric', '2016', 'SUV']
# ['Louise', 'Parry', '66', 'Female', 'Ford', 'Ram 1500 Quad Cab', '2003', 'Sedan, Coupe']
# ['June', 'Macdonald', '67', 'Female', 'Cadillac', 'Camaro', '2016', 'Sedan, Hatchback']
# ['Eileen', 'Lee', '55', 'Female', 'Volkswagen', 'Grand Cherokee', '2015', 'Sedan']
# ['Sian', 'Mason', '72', 'Female', 'Toyota', 'Armada', '1993', 'Hatchback, Convertible']
# ['Brett', 'Mason', '89', 'Male', 'Mercedes-Benz', 'Neon', '2010', 'Sedan']
# ['Joan', 'Clarke', '83', 'Female', 'Audi', 'Fusion', '2008', 'Van/Minivan']
# ['Lynne', 'Harris', '90', 'Female', 'Chevrolet', 'California', '2011', 'Coupe, Convertible']
# ['Tony', 'Singh', '77', 'Male', 'Ford', 'Ranger Super Cab', '1997', 'Pickup']
# ['Arthur', 'Austin', '61', 'Male', 'Dodge', 'Montana', '2018', 'Van/Minivan']
# ['Damien', 'Turner', '67', 'Male', 'Ford', 'TITAN XD Crew Cab', '2005', 'Pickup']
# ['Elaine', 'Andrews', '57', 'Female', 'Chrysler', 'NX', '1999', 'Coupe, Convertible']
# ['Dominic', 'Hayes', '48', 'Male', 'FIAT', 'XC90', '2000', 'Hatchback, Convertible']
# ['Sally', 'Holt', '57', 'Female', 'Saab', 'Equus', '2019', 'SUV']
# ['Lindsey', 'Davies', '85', 'Female', 'Toyota', 'Corsica', '1999', 'Sedan']
# ['Rhys', 'George', '48', 'Male', 'Lexus', 'Ram 2500 Mega Cab', '2018', 'Hatchback']
# ['Leonard', 'Lewis', '44', 'Male', 'Dodge', 'Odyssey', '1998', 'Sedan']
# ['Sarah', 'Parsons', '19', 'Female', 'Toyota', 'Acadia', '2018', 'Wagon']
# ['Kim', 'Baxter', '89', 'Female', 'Rolls-Royce', 'Forte', '2000', 'SUV']
# ['Danny', 'Evans', '32', 'Male', 'Acura', 'Jetta', '2011', 'Van/Minivan']
# ['Brett', 'Smith', '64', 'Male', 'Mercedes-Benz', 'Cayenne', '2004', 'SUV']
# ['Jane', 'Bradley', '46', 'Female', 'Ram', 'Veloster', '2019', 'Sedan']
# ['Paige', 'Smith', '60', 'Female', 'Kia', 'Express 2500 Cargo', '2009', 'Pickup']
# ['Kevin', 'Clarke', '72', 'Male', 'McLaren', 'F150 Regular Cab', '2011', 'Pickup']
# ['Ross', 'Parsons', '31', 'Male', 'Kia', 'Grand Vitara', '2008', 'Van/Minivan']
# ['Jay', 'Simpson', '75', 'Male', 'Dodge', 'Safari Passenger', '2015', 'Hatchback']
# ['Grace', 'Gray', '42', 'Female', 'GMC', 'GTI', '2012', 'Sedan']
# ['Clifford', 'Campbell', '63', 'Male', 'Oldsmobile', 'Challenger', '2010', 'Convertible, Coupe']
# ['Roger', 'Griffiths', '67', 'Male', 'Nissan', 'Colorado Crew Cab', '2015', 'Hatchback']
# ['Mathew', 'Coates', '50', 'Male', 'Dodge', 'C-Class', '2005', 'Sedan']
# ['Grace', 'Brown', '20', 'Female', 'Toyota', 'X-Type', '2018', 'Sedan, Wagon']
# ['Amanda', 'Jones', '48', 'Female', 'Mercury', 'A8', '2006', 'Coupe, Convertible']
# ['Darren', 'Nicholson', '91', 'Male', 'Pontiac', '3500 HD Regular Cab', '2001', 'Sedan']
# ['James', 'Butler', '81', 'Male', 'Oldsmobile', 'Vibe', '1999', 'Van/Minivan']
# ['Gareth', 'Sykes', '77', 'Male', 'Chrysler', 'Traverse', '1995', 'SUV']
# ['Pauline', 'Fox', '35', 'Female', 'Chevrolet', 'Crown Victoria', '1997', 'Pickup']
# ['Naomi', 'Williams', '82', 'Female', 'Scion', '500', '2007', 'Sedan']
# ['Benjamin', 'Griffin', '91', 'Male', 'Ford', 'ProMaster Cargo Van', '2003', 'SUV']
# ['Kevin', 'Harrison', '75', 'Male', 'Chevrolet', 'LX', '2017', 'Van/Minivan']
# ['Lydia', 'Thompson', '72', 'Female', 'Audi', 'Vandura 3500', '1997', 'SUV']
# ['Paige', 'Lees', '72', 'Female', 'Dodge', 'Eldorado', '2005', 'Sedan']
# ['Marc', 'Parker', '44', 'Male', 'INFINITI', 'Montana', '2017', 'Sedan']
# ['Stephen', 'Sullivan', '89', 'Male', 'Lexus', '3 Series', '1999', 'Coupe']
# ['Charlie', 'West', '36', 'Male', 'Lincoln', 'Regular Cab', '2009', 'Sedan']
# ['Ricky', 'Hill', '18', 'Male', 'BMW', 'Escalade ESV', '2000', 'Sedan']
# ['Bethan', 'Warren', '73', 'Female', 'Lincoln', 'Sierra 3500 HD Crew Cab', '2017', 'Van/Minivan']
# ['Graeme', 'Burns', '83', 'Male', 'Dodge', 'Silverado 3500 HD Extended Cab', '2002', 'Wagon']
# ['Brett', 'Hall', '28', 'Male', 'Cadillac', 'Ridgeline', '2020', 'Sedan']
# ['Richard', 'Hussain', '54', 'Male', 'Ford', 'Canyon Regular Cab', '2017', 'SUV']
# ['Frank', 'Martin', '72', 'Male', 'Honda', 'LS', '1993', 'Sedan']
# ['Harry', 'Fleming', '43', 'Male', 'Mercedes-Benz', 'Taurus X', '2015', 'Sedan']
# ['Yvonne', 'Thompson', '20', 'Female', 'Nissan', 'GT', '2019', 'Pickup']
# ['William', 'Brown', '46', 'Male', 'Mercedes-Benz', 'QX60', '2006', 'Van/Minivan']
# ['Ashleigh', 'Leach', '65', 'Female', 'Volvo', 'Sunfire', '2010', 'SUV']
# ['Wayne', 'Reeves', '48', 'Male', 'Kia', 'F250 Super Duty Super Cab', '2014', 'SUV']
# ['Anna', 'Parkinson', '34', 'Female', 'Ferrari', 'G5', '2015', 'Van/Minivan']
# ['Callum', 'Middleton', '48', 'Male', 'Audi', 'Camry', '2000', 'Sedan']
# ['Gary', 'Skinner', '47', 'Male', 'Subaru', 'Brooklands', '2004', 'Sedan, Wagon']
# ['Kerry', 'Smith', '19', 'Female', 'Suzuki', 'Murano', '1995', 'Sedan']
# ['Marion', 'James', '55', 'Female', 'Chrysler', '400 SE', '1993', 'Sedan']
# ['Amber', 'Stewart', '48', 'Female', 'Pontiac', 'Range Rover', '2006', 'Sedan']
# ['Tracy', 'Wilson', '71', 'Female', 'Audi', 'GLS', '2019', 'SUV']
# ['Toby', 'Barnes', '57', 'Male', 'Scion', 'Sonic', '2010', 'Pickup']
# ['Marcus', 'Atkinson', '47', 'Male', 'Dodge', 'F450 Super Duty Crew Cab', '2007', 'SUV']
# ['Georgia', 'Ellis', '66', 'Female', 'Hyundai', 'Optima', '2009', 'Van/Minivan']
# ['Damien', 'Sharp', '47', 'Male', 'Nissan', 'Mustang', '1993', 'Hatchback']
# ['Alexandra', 'Walker', '82', 'Female', 'Chrysler', 'SLK-Class', '2004', 'Pickup']
# ['Julie', 'Jones', '68', 'Female', 'Ford', 'Corvette', '2017', 'Hatchback']
# ['Tracy', 'Hill', '26', 'Female', 'Honda', 'S10 Extended Cab', '2014', 'Coupe, Convertible']
# ['Jacqueline', 'Cook', '68', 'Female', 'Pontiac', 'Sprinter 3500 Cargo', '2003', 'SUV']
# ['Lynne', 'Palmer', '43', 'Female', 'Volvo', 'Ridgeline', '2018', 'Coupe, Sedan, Convertible']
# ['Glen', 'Perry', '82', 'Male', 'Chevrolet', 'CX-30', '1998', 'Sedan, Coupe']
# ['Abdul', 'Finch', '74', 'Male', 'Mercedes-Benz', 'Brooklands', '2005', 'SUV']
# ['Benjamin', 'Pugh', '72', 'Male', 'GMC', 'Discovery', '2016', 'Pickup']
# ['Bruce', 'Harrison', '44', 'Male', 'Chevrolet', 'Edge', '1997', 'Pickup']
# ['Maurice', 'Jackson', '21', 'Male', 'GMC', 'Escape', '2008', 'Coupe, Convertible']
# ['Susan', 'Hughes', '37', 'Female', 'Chevrolet', 'Silverado 3500 HD Regular Cab', '1994', 'SUV']
# ['Heather', 'Goddard', '69', 'Female', 'Aston Martin', 'Skylark', '2006', 'Coupe']
# ['Georgia', 'Hughes', '41', 'Female', 'Buick', '5 Series', '2014', 'Van/Minivan']
# ['Stephanie', 'Gibson', '90', 'Female', 'Suzuki', 'Ram Van B250', '2002', 'Coupe']
# ['Jennifer', 'Spencer', '60', 'Female', 'Land Rover', 'C-Class', '2016', 'Sedan']
# ['Kimberley', 'Mahmood', '69', 'Female', 'Toyota', 'Explorer', '2012', 'SUV']
# ['Elaine', 'Evans', '40', 'Female', 'Ford', 'B-Series Regular Cab', '2007', 'Coupe, Convertible']
# ['Maurice', 'Pearson', '21', 'Male', 'Chevrolet', 'Civic', '2019', 'Pickup']
# ['Dorothy', 'Harvey', '68', 'Female', 'Ford', 'F150 SuperCrew Cab', '2019', 'Van/Minivan']
# ['Jennifer', 'Chamberlain', '25', 'Female', 'Chevrolet', 'Safari Passenger', '2003', 'Sedan, Coupe']
# ['John', 'Smith', '40', 'Male', 'Lamborghini', 'MPV', '2002', 'Sedan']
# ['Jane', 'Duncan', '35', 'Female', 'Ram', 'Grand Am', '2006', 'Sedan']
# ['Martyn', 'Smith', '84', 'Male', 'Subaru', 'Dakota Quad Cab', '2005', 'SUV']
# ['Laura', 'Lee', '85', 'Female', 'Chrysler', 'QX80', '1994', 'Sedan']
# ['Craig', 'Richardson', '60', 'Male', 'Acura', 'C-Class', '2014', 'SUV']
# ['Marilyn', 'Brown', '31', 'Female', 'Nissan', 'Range Rover Sport', '1995', 'SUV']
# ['Vanessa', 'Cox', '34', 'Female', 'Mitsubishi', 'Grand Prix', '2012', 'Sedan']
# ['Cameron', 'Hawkins', '42', 'Male', 'Cadillac', 'Crown Victoria', '1995', 'Van/Minivan']
# ['Abbie', 'Smith', '51', 'Female', 'Chevrolet', 'Silverado 2500 HD Crew Cab', '2016', 'Convertible']
# ['Ashleigh', 'Adams', '36', 'Female', 'Jeep', 'Discovery', '2006', 'SUV']
# ['Marie', 'Roberts', '31', 'Female', 'Acura', 'Silverado 1500 Regular Cab', '2017', 'Van/Minivan']
# ['Douglas', 'Williams', '39', 'Male', 'Volvo', 'LS', '1996', 'Sedan, Hatchback']
# ['Paige', 'Sullivan', '56', 'Female', 'INFINITI', 'Escalade ESV', '2002', 'SUV']
# ['Lucy', 'Wood', '63', 'Female', 'MAZDA', 'Canyon Regular Cab', '2008', 'Pickup']
# ['Iain', 'Shaw', '49', 'Male', 'Volvo', 'G-Class', '1993', 'Sedan']
# ['Rosie', 'Reed', '53', 'Female', 'MINI', 'RSX', '2002', 'SUV']
# ['Nicole', 'Smith', '88', 'Female', 'INFINITI', 'Range Rover Sport', '1996', 'Sedan']
# ['Patricia', 'Smith', '46', 'Female', 'BMW', 'Sprinter 2500 Cargo', '2008', 'Sedan']
# ['Ronald', 'Carter', '54', 'Male', 'Buick', 'ES', '2007', 'Van/Minivan']
# ['Hilary', 'Ward', '27', 'Female', 'Toyota', 'Stealth', '2018', 'Pickup']
# ['Raymond', 'Hall', '32', 'Male', 'Bentley', 'Tundra Regular Cab', '2004', 'Sedan']
# ['David', 'Hopkins', '55', 'Male', 'Ford', 'Oasis', '2003', 'SUV']
# ['Gillian', 'Foster', '78', 'Female', 'Chrysler', 'X5 M', '2006', 'Van/Minivan']
# ['Beth', 'Whittaker', '27', 'Female', 'Buick', 'City Express', '2017', 'Sedan']
# ['Ricky', 'Nolan', '38', 'Male', 'GMC', 'Camry Hybrid', '2008', 'Sedan']
# ['Richard', 'Collins', '91', 'Male', 'Ram', 'A3', '2000', 'Van/Minivan']
# ['Jessica', 'White', '36', 'Female', 'Mercedes-Benz', 'F350 Super Duty Super Cab', '2012', 'Pickup']
# ['Chelsea', 'Richardson', '31', 'Female', 'Nissan', 'Compass', '2001', 'SUV']
# ['Hollie', 'Webb', '29', 'Female', 'GMC', 'Sonoma Regular Cab', '1995', 'Convertible']
# ['Michelle', 'Reid', '57', 'Female', 'MAZDA', 'Transit 350 Van', '1995', 'Wagon, Convertible, Sedan']
# ['Stacey', "O'Donnell", '29', 'Female', 'Ram', 'Windstar Cargo', '1999', 'Van/Minivan']
# ['Sian', 'Whitehouse', '91', 'Female', 'Kia', 'New Beetle', '2011', 'Sedan']
# ['Lucy', 'Armstrong', '45', 'Female', 'INFINITI', 'Avalon', '2017', 'Hatchback']
# ['Patricia', 'Johnston', '65', 'Female', 'Nissan', 'Silverado 2500 HD Extended Cab', '1993', 'Convertible']
# ['Patrick', 'Young', '26', 'Male', 'Nissan', 'Grand Caravan Passenger', '1994', 'Sedan']
# ['Kelly', 'Sanderson', '36', 'Female', 'Toyota', 'Tiguan', '2012', 'Convertible']
# ['Nicole', 'Pritchard', '42', 'Female', 'Honda', 'S6', '1995', 'SUV']
# ['Barbara', 'Kemp', '64', 'Female', 'Ford', 'Silverado 2500 HD Regular Cab', '2019', 'SUV']
# ['Billy', 'Whitehead', '20', 'Male', 'Dodge', 'Camaro', '1994', 'Pickup']
# ['Jodie', 'Thomas', '87', 'Female', 'Chevrolet', 'Tracer', '2017', 'Sedan']
# ['Bryan', 'Yates', '59', 'Male', 'Mercedes-Benz', 'Caliber', '2009', 'Van/Minivan']
# ['Martyn', 'Harris', '78', 'Male', 'Toyota', 'Galant', '2008', 'Hatchback']
# ['Liam', 'Walton', '52', 'Male', 'Mercury', 'Tundra Double Cab', '2012', 'Sedan']
# ['Bethany', 'Pratt', '46', 'Female', 'Lincoln', 'F250 Crew Cab', '1994', 'SUV']
# ['Jamie', 'John', '82', 'Male', 'BMW', 'Justy', '2008', 'SUV']
# ['Marian', 'Edwards', '80', 'Female', 'Chevrolet', 'Suburban 2500', '2019', 'Coupe, Convertible']
# ['Max', 'Clarke', '20', 'Male', 'BMW', 'Mariner', '1995', 'SUV']
# ['Marion', 'Hughes', '78', 'Female', 'Pontiac', 'Fit', '2010', 'Hatchback, Convertible']
# ['Mark', 'Schofield', '18', 'Male', 'Porsche', 'G-Series 3500', '2010', 'SUV']
# ['Keith', 'Saunders', '56', 'Male', 'Mercedes-Benz', 'Hombre Spacecab', '2011', 'Coupe']
# ['Max', 'Johnson', '47', 'Male', 'BMW', 'i3', '2018', 'Sedan']
# ['Bradley', 'Norton', '46', 'Male', 'Ford', 'Discovery Sport', '1997', 'Wagon']
# ['Simon', 'Thomas', '77', 'Male', 'Lexus', 'Stinger', '2000', 'Sedan, Hatchback']
# ['Joel', 'Mason', '43', 'Male', 'Mercedes-Benz', 'tC', '1992', 'Sedan, Wagon']
# ['Gavin', 'Horton', '38', 'Male', 'Chevrolet', 'XE', '2005', 'Pickup']
# ['Jack', 'Harris', '50', 'Male', 'Ford', 'Silverado 3500 HD Regular Cab', '1995', 'Pickup']
# ['Billy', 'Goodwin', '85', 'Male', 'Dodge', 'Silverado 3500 Regular Cab', '2013', 'Pickup']
# ['Dominic', 'Thomas', '73', 'Male', 'Buick', '323', '1999', 'Hatchback']
# ['Graham', 'Fuller', '30', 'Male', 'Ford', 'Taurus', '2019', 'Sedan']
# ['Joe', 'Benson', '60', 'Male', 'GMC', 'MPV', '1999', 'Coupe, Convertible']
# ['Donald', 'Price', '21', 'Male', 'Volkswagen', '4Runner', '2003', 'SUV']
# ['Jean', 'Carr', '30', 'Female', 'Honda', 'Mountaineer', '2011', 'SUV']
# ['Hugh', 'Long', '46', 'Male', 'Cadillac', 'SL-Class', '2006', 'Sedan, Wagon']
# ['Sian', 'Lees', '82', 'Female', 'Mitsubishi', 'S-Class', '2012', 'Sedan']
# ['Bradley', 'Butler', '61', 'Male', 'Hyundai', 'Renegade', '2019', 'Sedan']
# ['Joyce', 'Ali', '88', 'Female', 'Alfa Romeo', 'Canyon Crew Cab', '2010', 'SUV']
# ['Michael', 'Harrison', '21', 'Male', 'GMC', 'Exige', '1993', 'Hatchback']
# ['Marc', 'Howard', '23', 'Male', 'Hyundai', 'Forte', '2020', 'Wagon, Sedan']
# ['Jean', 'Gill', '47', 'Female', 'Kia', '911', '2000', 'Coupe']
# ['Liam', 'Nicholls', '73', 'Male', 'Chrysler', 'Mark VIII', '2005', 'SUV']
# ['Ryan', 'Walker', '63', 'Male', 'BMW', 'Wrangler', '2008', 'Sedan, Coupe']
# ['Rachel', 'Price', '26', 'Female', 'Nissan', 'Terraza', '2002', 'SUV']
# ['Mohammad', 'Green', '27', 'Male', 'Nissan', 'SQ5', '2003', 'Pickup']
# ['Alexandra', 'James', '83', 'Female', 'Mitsubishi', 'Sephia', '2009', 'Sedan']
# ['Wendy', 'Bailey', '80', 'Female', 'Daewoo', 'Cavalier', '2014', 'SUV']
# ['Callum', 'Burton', '26', 'Male', 'Mercedes-Benz', 'X3', '2019', 'Convertible']
# ['Samuel', 'Hawkins', '74', 'Male', 'Oldsmobile', 'GLA', '2016', 'Hatchback']
# ['Francis', 'Holmes', '42', 'Male', 'Oldsmobile', 'LeBaron', '1992', 'Sedan']
# ['Dawn', 'Banks', '46', 'Female', 'Mercury', 'EX', '2019', 'Pickup']
# ['Ann', 'Richards', '81', 'Female', 'Scion', 'Verano', '2011', 'Van/Minivan']
# ['Josh', 'Gill', '30', 'Male', 'Hyundai', 'Yukon XL 1500', '2017', 'Sedan']
# ['Mandy', 'Stewart', '44', 'Female', 'Mercedes-Benz', 'Viper', '2012', 'Pickup']
# ['Holly', 'Smith', '61', 'Female', 'MAZDA', 'Grand Marquis', '2019', 'Coupe']
# ['Lawrence', 'Brown', '69', 'Male', 'Chevrolet', 'Altima', '1994', 'Van/Minivan']
# ['Catherine', 'Ashton', '87', 'Female', 'Nissan', 'E350 Super Duty Passenger', '2007', 'Van/Minivan']
# ['David', 'Parkinson', '57', 'Male', 'Mercedes-Benz', 'Scoupe', '2006', 'Van/Minivan']
# ['Daniel', 'Barker', '45', 'Male', 'Ford', '200', '2008', 'Pickup']
# ['Gerald', 'Taylor', '37', 'Male', 'Honda', '5 Series', '2009', 'Pickup']
# ['Sandra', 'Chapman', '59', 'Female', 'Lincoln', '90', '2000', 'Pickup']
# ['Chelsea', 'Stephens', '50', 'Female', 'MAZDA', 'Vigor', '2004', 'Coupe']
# ['Emma', 'Watkins', '37', 'Female', 'GMC', 'Caravan Passenger', '2014', 'Sedan']
# ['Alan', 'Hughes', '75', 'Male', 'GMC', 'Range Rover', '1992', 'Pickup']
# ['Gail', 'Green', '33', 'Female', 'Lincoln', 'Leganza', '2009', 'Sedan, Wagon']
# ['Abdul', 'Fisher', '38', 'Male', 'Toyota', 'Sportage', '2000', 'Coupe']
# ['Abigail', 'Ellis', '76', 'Female', 'Nissan', 'Rally Wagon G3500', '2006', 'Sedan']
# ['Megan', 'Wright', '18', 'Female', 'Hyundai', 'Ram 1500 Regular Cab', '2009', 'Hatchback, Sedan']
# ['Gemma', 'Smith', '76', 'Female', 'INFINITI', 'XC70', '2010', 'Pickup']
# ['Dorothy', 'Howard', '40', 'Female', 'Subaru', 'Tundra Access Cab', '2008', 'Van/Minivan']
# ['Clive', 'Smith', '62', 'Male', 'MAZDA', 'iQ', '2002', 'Sedan']
# ['Ryan', 'Wilkinson', '65', 'Male', 'Toyota', 'DBS', '2014', 'SUV']
# ['Andrew', 'Wilson', '22', 'Male', 'BMW', 'Envoy', '2019', 'SUV']
# ['Ross', 'Foster', '71', 'Male', 'GMC', '88', '1992', 'Van/Minivan']
# ['Tony', 'Gough', '69', 'Male', 'Ford', 'Spacecab', '2014', 'SUV']
# ['Paige', 'Stewart', '38', 'Female', 'INFINITI', 'GR Supra', '2001', 'Pickup']
# ['Irene', 'Bates', '52', 'Female', 'Chrysler', 'F250 Super Duty Super Cab', '2006', 'Sedan']
# ['Darren', 'Curtis', '81', 'Male', 'Land Rover', 'Sorento', '2004', 'Hatchback']
# ['Michelle', 'Smith', '71', 'Female', 'Audi', 'Beetle', '2007', 'Sedan']
# ['Jamie', 'Harris', '22', 'Male', 'Jeep', 'Suburban 1500', '2015', 'SUV']
# ['Nigel', 'Powell', '20', 'Male', 'GMC', 'Mercedes-AMG E-Class', '2004', 'Sedan']
# ['Owen', 'Brennan', '55', 'Male', 'Lexus', 'Civic', '2019', 'Hatchback, Sedan, Convertible']
# ['Hannah', 'Sharp', '59', 'Female', 'Toyota', 'Voyager', '2016', 'Wagon, Sedan, Coupe']
# ['Marion', 'Edwards', '49', 'Female', 'Ram', 'S40', '2020', 'Pickup']
# ['Sophie', 'Wells', '52', 'Female', 'INFINITI', 'CR-V', '2020', 'Coupe, Convertible']
# ['Terry', 'Edwards', '82', 'Male', 'INFINITI', '570GT', '2019', 'Pickup']
# ['Marian', 'Turner', '31', 'Female', 'Honda', 'TT', '2005', 'Van/Minivan']
# ['Rosie', 'Smith', '86', 'Female', 'Lamborghini', 'Avalon', '2001', 'Sedan']
# ['Peter', 'Barrett', '51', 'Male', 'GMC', 'allroad', '2001', 'Pickup']
# ['Tom', 'Nash', '83', 'Male', 'Chevrolet', 'Avalanche', '1997', 'Pickup']
# ['Roger', 'Shaw', '68', 'Male', 'Dodge', 'Ram 1500 Regular Cab', '2020', 'Coupe']
# ['Steven', 'Gray', '61', 'Male', 'Volkswagen', '88', '1998', 'Van/Minivan']
# ['Alexander', 'Miah', '44', 'Male', 'Lincoln', 'A4', '2006', 'SUV']
# ['Conor', 'Baker', '53', 'Male', 'INFINITI', 'Explorer', '1998', 'Coupe']
# ['Lawrence', 'Murphy', '20', 'Male', 'Acura', 'MDX', '2002', 'Sedan']
# ['Kevin', "O'Neill", '36', 'Male', 'Nissan', 'Encore', '2000', 'Coupe']
# ['Stacey', 'McDonald', '57', 'Female', 'GMC', 'Skylark', '2001', 'Van/Minivan']
# ['Mitchell', 'Moran', '40', 'Male', 'Chevrolet', 'ProMaster Cargo Van', '2018', 'Coupe, Sedan']
# ['Carolyn', 'Williams', '57', 'Female', 'Chevrolet', 'Camry', '1997', 'Sedan']
# ['Mandy', 'Stewart', '33', 'Female', 'Ford', 'NV2500 HD Cargo', '1993', 'Sedan']
# ['Chloe', 'Gardiner', '68', 'Female', 'Rolls-Royce', 'Prius v', '2009', 'SUV']
# ['Karen', 'Burton', '38', 'Female', 'INFINITI', 'E-Class', '2011', 'SUV']
# ['Jenna', 'Turner', '43', 'Female', 'GMC', 'I', '2005', 'Van/Minivan']
# ['Roger', 'White', '19', 'Male', 'Honda', 'MX-5 Miata RF', '2018', 'Sedan']
# ['Charlene', 'North', '60', 'Female', 'Jaguar', 'Sunfire', '2007', 'Sedan, Hatchback']
# ['Katie', 'Shaw', '91', 'Female', 'Toyota', '500L', '2011', 'Coupe, Sedan, Wagon']
# ['Victoria', 'Smith', '30', 'Female', 'Mercedes-Benz', 'Sierra 2500 Regular Cab', '2004', 'SUV']
# ['Duncan', 'Miller', '71', 'Male', 'Mitsubishi', 'Accent', '2020', 'Pickup']
# ['Anna', 'Allen', '48', 'Female', 'Chevrolet', 'Rogue', '2017', 'Van/Minivan']
# ['Julian', 'Holmes', '42', 'Male', 'Nissan', 'R8', '2016', 'Coupe, Convertible']
# ['Pamela', 'Cox', '83', 'Female', 'Chevrolet', 'Metro', '2007', 'SUV']
# ['Debra', 'Parker', '59', 'Female', 'Suzuki', 'Golf', '1999', 'Coupe, Convertible']
# ['Carl', 'Davey', '60', 'Male', 'Ford', '929', '1993', 'Sedan']
# ['Sam', 'Jones', '86', 'Male', 'Lexus', 'XL7', '2008', 'Wagon']
# ['Marian', 'Blake', '59', 'Female', 'Ford', 'Sprinter 3500 Cargo', '2014', 'SUV']
# ['Victoria', 'Morrison', '49', 'Female', 'Kia', 'Imperial', '2015', 'Convertible']
# ['Carl', 'Carter', '35', 'Male', 'Volkswagen', 'Avalon', '1995', 'Hatchback']
# ['Kathleen', 'Hall', '82', 'Female', 'GMC', 'Maxima', '2012', 'Van/Minivan']
# ['Cameron', 'Walters', '47', 'Male', 'Chevrolet', 'Outlander', '2002', 'Coupe, Convertible']
# ['Mary', 'James', '21', 'Female', 'Rolls-Royce', 'FX', '2000', 'Hatchback']
# ['Gareth', 'Hayward', '32', 'Male', 'Jeep', 'Explorer', '2009', 'Coupe']
# ['Angela', 'Smith', '55', 'Female', 'Jeep', 'Suburban 2500', '2001', 'Pickup']
# ['Charles', 'Roberts', '84', 'Male', 'Honda', 'TL', '2011', 'Convertible']
# ['Albert', 'Cooke', '52', 'Male', 'Chevrolet', 'Protege', '2014', 'Pickup']
# ['Malcolm', 'Moore', '48', 'Male', 'Kia', 'G-Class', '2009', 'SUV']
# ['Tina', 'Taylor', '19', 'Female', 'Mercedes-Benz', 'Grand Cherokee', '2002', 'Hatchback']
# ['Justin', 'Sinclair', '35', 'Male', 'Ford', 'Expedition EL', '2005', 'SUV']
# ['Owen', 'Hall', '83', 'Male', 'Cadillac', 'Golf', '2002', 'Pickup']
# ['Jason', 'Spencer', '88', 'Male', 'Kia', '4C Spider', '2009', 'SUV']
# ['Alison', 'Adams', '46', 'Female', 'Chevrolet', 'i-370 Extended Cab', '1998', 'Coupe']
# ['Jill', 'Lambert', '67', 'Female', 'Chrysler', 'Durango', '2008', 'Sedan']
# ['Alice', 'Hart', '36', 'Female', 'Subaru', '2500 Extended Cab', '1996', 'Sedan, Coupe']
# ['George', 'Weston', '18', 'Male', 'Toyota', 'M6', '2017', 'Sedan, Coupe']
# ['Roy', 'Watson', '51', 'Male', 'Toyota', 'Grand Cherokee', '2008', 'Wagon']
# ['Rachael', 'Singh', '25', 'Female', 'Ford', 'Caravan Passenger', '2005', 'SUV']
# ['Laura', 'Walker', '28', 'Female', 'BMW', 'Swift', '2010', 'SUV']
# ['Bruce', 'Webb', '58', 'Male', 'Chevrolet', 'CT', '2015', 'SUV']
# ['Charlene', 'Morris', '26', 'Female', 'Mercedes-Benz', 'ES', '2016', 'Pickup']
# ['Elizabeth', 'Holmes', '23', 'Female', 'Cadillac', 'Transit 250 Van', '2019', 'Van/Minivan']
# ['Rosie', 'Edwards', '78', 'Female', 'Scion', 'Silverado 2500 HD Extended Cab', '2008', 'SUV']
# ['Mary', 'Stokes', '78', 'Female', 'Chevrolet', 'Suburban 3500HD', '2003', 'Pickup']
# ['Michelle', 'Wilson', '22', 'Female', 'Subaru', 'Express 2500 Passenger', '2000', 'Sedan']
# ['Sian', 'Roberts', '48', 'Female', 'Pontiac', 'Hombre Regular Cab', '2020', 'Sedan, Wagon']
# ['Beth', 'Patel', '89', 'Female', 'Hyundai', 'Yukon XL 1500', '2003', 'Sedan, Wagon']
# ['Luke', 'Pollard', '89', 'Male', 'GMC', 'Sprinter 2500 Passenger', '2016', 'Convertible']
# ['Lucy', 'White', '48', 'Female', 'Audi', 'Grand Cherokee', '2000', 'SUV']
# ['Amy', 'Johnson', '74', 'Female', 'Cadillac', 'Dakota Club Cab', '2008', 'Sedan']
# ['Conor', 'Martin', '67', 'Male', 'Dodge', 'S-Class', '2020', 'Van/Minivan']
# ['Bryan', 'Warner', '63', 'Male', 'Buick', 'BRZ', '1994', 'SUV']
# ['Sandra', 'Walker', '86', 'Female', 'Honda', 'Prius c', '2004', 'Van/Minivan']
# ['Jason', 'Fry', '58', 'Male', 'Ferrari', 'F250 Super Duty Crew Cab', '1999', 'SUV']
# ['Georgina', 'Martin', '69', 'Female', 'Honda', 'Corolla', '2012', 'Pickup']
# ['Mark', 'Morrison', '44', 'Male', 'Jaguar', 'Suburban 3500HD', '1993', 'Coupe']
# ['Malcolm', 'Matthews', '67', 'Male', 'Ford', 'Fiesta', '2015', 'SUV']
# ['Roger', 'Burton', '62', 'Male', 'Mercedes-Benz', 'Alero', '2013', 'SUV']
# ['Ellie', 'Macdonald', '63', 'Female', 'MINI', 'RLX', '2000', 'Coupe']
# ['Christopher', 'Roberts', '46', 'Male', 'Chevrolet', 'Jimmy', '1992', 'Van/Minivan']
# ['Josh', 'Morgan', '54', 'Male', 'Ford', 'GTI', '2019', 'Convertible, Coupe']
# ['Caroline', 'Cooper', '31', 'Female', 'Dodge', 'ATS-V', '2016', 'SUV']
# ['Hannah', 'Hartley', '43', 'Female', 'Chevrolet', '612 Scaglietti', '2014', 'Van/Minivan']
# ['Allan', 'Powell', '82', 'Male', 'Ford', 'Sequoia', '1998', 'Coupe']
# ['Bernard', 'Shaw', '72', 'Male', 'GMC', 'Savana 3500 Passenger', '1993', 'SUV']
# ['Scott', 'Williams', '89', 'Male', 'Dodge', 'NV3500 HD Passenger', '1997', 'Van/Minivan']
# ['Frederick', 'Patterson', '47', 'Male', 'Toyota', 'Xtra Cab', '2000', 'SUV']
# ['Joseph', 'Wood', '80', 'Male', 'Jeep', 'XK', '2008', 'Pickup']
# ['Stanley', 'Woods', '53', 'Male', 'INFINITI', 'Discovery Series II', '2018', 'Pickup']
# ['Graeme', 'Osborne', '84', 'Male', 'Ford', 'X5', '2015', 'Hatchback']
# ['Jenna', 'Knight', '61', 'Female', 'Lexus', 'V60', '2017', 'SUV']
# ['Kyle', 'Moore', '75', 'Male', 'Chevrolet', 'Xterra', '2000', 'Sedan']
# ['Hilary', 'Stewart', '62', 'Female', 'Nissan', 'Sierra 2500 HD Crew Cab', '2006', 'Pickup']
# ['Diane', 'Sullivan', '51', 'Female', 'Audi', 'Suburban 2500', '2011', 'SUV']
# ['Stewart', 'Powell', '81', 'Male', 'Porsche', 'Prius', '1997', 'SUV']
# ['Amber', 'Howells', '71', 'Female', 'Subaru', 'I', '2017', 'SUV']
# ['Sian', 'Walsh', '85', 'Female', 'Nissan', 'Pathfinder', '2014', 'Coupe, Convertible']
# ['Sharon', 'Morris', '48', 'Female', 'Scion', 'DeVille', '2011', 'Van/Minivan']
# ['Hilary', 'Read', '37', 'Female', 'Nissan', 'M', '2017', 'Van/Minivan']
# ['Paige', 'Edwards', '71', 'Female', 'Ford', 'Dakota Quad Cab', '2005', 'Sedan']
# ['Alan', 'Brown', '34', 'Male', 'Lincoln', 'Armada', '2010', 'Coupe, Convertible']
# ['Patricia', 'Lee', '29', 'Female', 'INFINITI', 'Lancer', '2003', 'Coupe, Convertible']
# ['Fiona', 'Wilkinson', '44', 'Female', 'Ford', 'Savana 2500 Cargo', '2000', 'Sedan, Coupe']
# ['Joan', 'Evans', '58', 'Female', 'GMC', 'Golf', '2018', 'Sedan']
# ['Holly', 'Clarke', '78', 'Female', 'Ford', 'GT-R', '2009', 'Sedan']
# ['Clive', 'Swift', '45', 'Male', 'Hyundai', 'Rapide S', '2013', 'Van/Minivan']
# ['Julian', 'Anderson', '36', 'Male', 'Ford', 'MX-5 Miata RF', '2016', 'Sedan']
# ['Geoffrey', 'Dale', '82', 'Male', 'Hyundai', 'F150 SuperCrew Cab', '2017', 'Coupe, Convertible']
# ['Hannah', 'Lloyd', '40', 'Female', 'Volkswagen', 'Protege', '2020', 'SUV']
# ['Antony', 'Lewis', '22', 'Male', 'Dodge', 'Escalade', '1995', 'Pickup']
# ['Lewis', 'Miles', '24', 'Male', 'Ford', 'Genesis Coupe', '2018', 'Pickup']
# ['Dean', 'Walsh', '49', 'Male', 'Chevrolet', 'Range Rover Evoque', '2011', 'SUV']
# ['Maureen', 'Hayes', '55', 'Female', 'Nissan', 'LX', '1992', 'Sedan']
# ['Patrick', 'Campbell', '68', 'Male', 'Toyota', 'Transit 350 Van', '1994', 'Sedan']
# ['Amelia', 'Warren', '34', 'Female', 'Lexus', '2500 Club Coupe', '1997', 'Convertible']
# ['Edward', 'McKenzie', '33', 'Male', 'Dodge', 'S10 Extended Cab', '2006', 'Hatchback']
# ['Frances', 'West', '49', 'Female', 'GMC', 'Flex', '1997', 'Coupe']
# ['Katherine', 'Bishop', '43', 'Female', 'MAZDA', 'Forte', '2019', 'Van/Minivan']
# ['Mohammad', 'Lewis', '80', 'Male', 'Chevrolet', 'Sprinter 2500 Passenger', '2008', 'Pickup']
# ['Angela', 'McDonald', '71', 'Female', 'Nissan', 'Matrix', '1994', 'Hatchback']
# ['Daniel', 'Chan', '51', 'Male', 'Toyota', 'SLK-Class', '2002', 'Van/Minivan']
# ['Samantha', 'Vaughan', '65', 'Female', 'BMW', 'Quest', '2006', 'Sedan']
# ['Abbie', 'Knight', '88', 'Female', 'Toyota', '370Z', '1994', 'Wagon']
# ['Hugh', 'Bennett', '45', 'Male', 'GMC', 'Skylark', '2020', 'Pickup']
# ['Dylan', 'Jones', '50', 'Male', 'Kia', 'GS', '2010', 'SUV']
# ['Philip', 'Richardson', '19', 'Male', 'Toyota', 'Vantage', '2008', 'Sedan']
# ['Jack', 'Williams', '47', 'Male', 'Buick', 'F250 Super Duty Super Cab', '2010', 'Sedan']
# ['Jasmine', 'Preston', '78', 'Female', 'Buick', 'XK', '2007', 'SUV']
# ['Stephanie', 'Bray', '51', 'Female', 'GMC', 'RAV4 Hybrid', '2016', 'SUV']
# ['Alan', 'Andrews', '18', 'Male', 'Nissan', '911', '2017', 'Sedan']
# ['Sean', 'Young', '40', 'Male', 'Ford', 'Liberty', '2013', 'Wagon, Sedan']
# ['Kieran', 'Curtis', '25', 'Male', 'INFINITI', 'Continental', '2004', 'Convertible']
# ['Dorothy', 'Roberts', '72', 'Female', 'Ford', 'A6', '2016', 'SUV']
# ['Jordan', 'Lynch', '88', 'Male', 'Acura', 'Vibe', '2004', 'Pickup']
# ['Neil', 'Miles', '21', 'Male', 'Jeep', 'Sebring', '2010', 'SUV']
# ['Kim', 'Griffiths', '82', 'Female', 'Ford', 'LeBaron', '1994', 'Van/Minivan']
# ['Valerie', 'Carroll', '36', 'Female', 'Chevrolet', 'Sierra 2500 Extended Cab', '2008', 'Sedan']
# ['Chloe', 'Short', '36', 'Female', 'Ford', 'Viper', '1995', 'Wagon, Sedan']
# ['Elaine', 'Newton', '70', 'Female', 'GMC', 'Tribeca', '1992', 'Hatchback']
# ['Clive', 'Davies', '35', 'Male', 'Chevrolet', 'Tundra Access Cab', '2012', 'Sedan']
# ['Jeremy', 'Reid', '20', 'Male', 'Jaguar', 'Murano', '2016', 'Sedan, Coupe']
# ['Angela', 'Gray', '23', 'Female', 'Ford', 'Clubman', '2001', 'Sedan, Coupe']
# ['Kyle', 'Thomas', '46', 'Male', 'Mitsubishi', 'S-Class', '2011', 'Convertible']
# ['Geoffrey', 'King', '44', 'Male', 'MAZDA', 'Outlook', '2001', 'SUV']
# ['Neil', 'Dunn', '44', 'Male', 'GMC', 'F150 Super Cab', '2012', 'Sedan, Coupe']
# ['Elliott', 'Daniels', '33', 'Male', 'Ram', 'S8', '2005', 'SUV']
# ['Barbara', 'Williams', '48', 'Female', 'Nissan', 'Sierra 3500 HD Crew Cab', '2015', 'SUV']
# ['Alexandra', 'Ford', '76', 'Female', 'Audi', 'Range Rover Sport', '2000', 'Sedan']
# ['Kimberley', 'Coles', '25', 'Female', 'GMC', '3 Series', '2014', 'SUV']
# ['Donna', 'Hart', '39', 'Female', 'Toyota', 'M', '2011', 'Sedan']
# ['Abbie', 'Wright', '60', 'Female', 'Plymouth', 'xB', '2007', 'SUV']
# ['Alexandra', 'Saunders', '43', 'Female', 'Ford', 'Ioniq Hybrid', '2015', 'Pickup']
# ['Amber', 'Hammond', '33', 'Female', 'BMW', 'Optima', '2017', 'Pickup']
# ['Elliot', 'Stevens', '44', 'Male', 'Toyota', 'Gallardo', '2013', 'Hatchback, Sedan, Convertible']
# ['Marc', 'Brown', '71', 'Male', 'Volkswagen', 'Grand Cherokee', '1992', 'Pickup']
# ['Stephanie', 'Knight', '86', 'Female', 'Chevrolet', 'Yukon', '1998', 'Coupe, Convertible']
# ['Anna', 'Austin', '49', 'Female', 'smart', 'Monaco', '2001', 'Sedan, Coupe']
# ['Justin', 'Gardiner', '22', 'Male', 'Pontiac', 'Rondo', '2002', 'Sedan, Wagon']
# ['Gary', 'Jackson', '86', 'Male', 'Toyota', 'ES', '2013', 'Sedan']
# ['Allan', 'Gibson', '65', 'Male', 'Chevrolet', 'Ram 2500 Quad Cab', '2020', 'Pickup']
# ['Joan', 'Potter', '89', 'Female', 'Oldsmobile', 'SRX', '2020', 'Hatchback, Convertible']
# ['Kelly', 'Fry', '89', 'Female', 'Nissan', 'Trax', '2013', 'Sedan']
# ['Maurice', 'Hunter', '21', 'Male', 'Ford', 'xD', '2008', 'Pickup']
# ['Melissa', 'Chapman', '82', 'Female', 'Dodge', 'Passport', '2002', 'SUV']
# ['Peter', 'Ford', '46', 'Male', 'Hyundai', 'TL', '2008', 'Coupe']
# ['Conor', 'Wood', '51', 'Male', 'Hyundai', 'Tacoma Xtracab', '1998', 'Sedan']
# ['Sally', 'Brown', '52', 'Female', 'McLaren', 'Azure', '1996', 'Sedan']
# ['Douglas', 'Jackson', '23', 'Male', 'Ram', 'S-Class', '2011', 'Pickup']
# ['Carol', 'Wade', '78', 'Female', 'Chevrolet', 'Grand Marquis', '2007', 'Pickup']
# ['Hugh', 'Wright', '80', 'Male', 'Jaguar', 'LS', '2012', 'SUV']
# ['Michael', 'Jones', '48', 'Male', 'Saturn', 'Accord', '2011', 'Sedan']
# ['Dorothy', 'Davies', '63', 'Female', 'Honda', 'V70', '2005', 'SUV']
# ['Ann', 'Thompson', '23', 'Female', 'Ford', 'Viper', '2007', 'SUV']
# ['Melissa', 'Lee', '80', 'Female', 'Ford', 'CX-9', '2017', 'Convertible']
# ['Mary', 'Sullivan', '34', 'Female', 'GMC', 'Prizm', '2009', 'Van/Minivan']
# ['Iain', 'Cook', '63', 'Male', 'Pontiac', '3-Sep', '2019', 'Pickup']
# ['Leonard', 'Blake', '57', 'Male', 'Audi', 'Grand Cherokee', '2001', 'Hatchback']
# ['Emily', 'Summers', '27', 'Female', 'Volvo', '1500 Quad Cab', '2007', 'SUV']
# ['James', 'Parker', '31', 'Male', 'Toyota', 'Camaro', '2006', 'Pickup']
# ['Luke', 'Smith', '59', 'Male', 'GMC', 'Accord', '2002', 'Van/Minivan']
# ['Beth', 'Skinner', '67', 'Female', 'Buick', 'Eclipse', '1998', 'SUV']
# ['Mohammed', 'Lawson', '52', 'Male', 'Chevrolet', 'CX-7', '2020', 'Pickup']
# ['Jane', 'Thomas', '31', 'Female', 'Ford', '500c Abarth', '2018', 'Convertible, Hatchback']
# ['Caroline', 'Lewis', '51', 'Female', 'Dodge', 'M', '2008', 'Sedan']
# ['Damien', 'Campbell', '23', 'Male', 'Nissan', 'Sierra 3500 HD Crew Cab', '2016', 'SUV']
# ['Abbie', 'Davies', '71', 'Female', 'BMW', 'Econoline E250 Cargo', '2018', 'Coupe, Convertible']
# ['Guy', 'Hamilton', '59', 'Male', 'Hyundai', 'Park Avenue', '2005', 'SUV']
# ['Steven', 'Webster', '20', 'Male', 'Nissan', '500 SEL', '2017', 'Van/Minivan']
# ['Claire', 'Cooper', '89', 'Female', 'Volkswagen', 'Expedition EL', '2016', 'Convertible, Hatchback']
# ['Frederick', 'Wright', '70', 'Male', 'Honda', 'GS', '1997', 'Convertible, Sedan, Coupe']
# ['Clifford', 'Coles', '29', 'Male', 'Chevrolet', 'Passat', '1997', 'SUV']
# ['Andrea', 'Harris', '63', 'Female', 'Mercedes-Benz', 'Z4', '2009', 'Sedan, Hatchback']
# ['Anne', 'White', '86', 'Female', 'Jeep', '164', '2001', 'Sedan']
# ['Lee', 'Hart', '69', 'Male', 'Subaru', 'Town & Country', '1992', 'Sedan, Coupe']
# ['Victor', 'Taylor', '44', 'Male', 'Ford', 'Caravan Cargo', '2001', 'Sedan, Coupe']
# ['Neil', 'Reid', '43', 'Male', 'Dodge', 'Sentra', '1996', 'Sedan']
# ['Philip', 'Greenwood', '29', 'Male', 'Mitsubishi', 'Precis', '2005', 'Sedan, Coupe']
# ['Jeremy', 'White', '87', 'Male', 'Ford', 'Transit 150 Van', '1998', 'SUV']
# ['Rosemary', 'Poole', '89', 'Female', 'Lincoln', 'Shadow', '1998', 'Van/Minivan']
# ['Ruth', 'Walton', '45', 'Female', 'Toyota', 'XC90', '1995', 'Convertible']
# ['Kathleen', 'Fisher', '33', 'Female', 'Volvo', 'Elantra GT', '2012', 'Convertible, Coupe']
# ['Brett', 'Mitchell', '62', 'Male', 'Ford', 'Beetle', '2017', 'Coupe']
# ['Keith', 'Patel', '22', 'Male', 'Chevrolet', 'Sierra 3500 Regular Cab', '2013', 'Coupe']
# ['Joanna', 'James', '36', 'Female', 'Ford', 'GT-R', '2011', 'Van/Minivan']
# ['Leon', 'Wyatt', '42', 'Male', 'Dodge', '5-Sep', '2012', 'Van/Minivan']
# ['Jay', 'Williamson', '88', 'Male', 'Oldsmobile', 'Wrangler', '2008', 'Hatchback']
# ['Amanda', 'Holmes', '26', 'Female', 'Chevrolet', '57', '2015', 'Hatchback, Sedan']
# ['Abigail', 'Smith', '35', 'Female', 'Mercedes-Benz', 'CLK-Class', '1996', 'SUV']
# ['Michelle', 'Brown', '34', 'Female', 'Chevrolet', 'Ram 3500 Quad Cab', '2011', 'Van/Minivan']
# ['Matthew', 'Taylor', '55', 'Male', 'Bentley', 'Tundra CrewMax', '2013', 'Pickup']
# ['Damien', 'Kay', '30', 'Male', 'Land Rover', 'Rio', '2013', 'Wagon']
# ['Heather', 'Roberts', '70', 'Female', 'Saab', 'Convertible', '2018', 'SUV']
# ['Jamie', 'Perry', '24', 'Male', 'Mercedes-Benz', 'TITAN XD Crew Cab', '1994', 'SUV']
# ['Maurice', 'Randall', '69', 'Male', 'Maserati', 'Ridgeline', '2003', 'Van/Minivan']
# ['Joan', 'Cook', '51', 'Female', 'Ram', 'Pacifica', '2004', 'SUV']
# ['Joanne', 'Howell', '60', 'Female', 'Dodge', 'RAV4', '2006', 'Sedan']
# ['Abbie', 'Rose', '51', 'Female', 'BMW', 'Transit Connect Passenger', '2013', 'Sedan, Convertible']
# ['Danny', 'Thomson', '38', 'Male', 'Hyundai', 'Grand Marquis', '2006', 'Coupe, Convertible']
# ['Deborah', 'Williams', '30', 'Female', 'Oldsmobile', 'H1', '2008', 'Pickup']
# ['Pamela', 'Ford', '23', 'Female', 'Volkswagen', 'Coupe', '1998', 'Van/Minivan']
# ['Jennifer', 'Fry', '19', 'Female', 'Chevrolet', 'Integra', '2003', 'Sedan, Coupe, Convertible']
# ['Wendy', 'Parkes', '35', 'Female', 'Mitsubishi', 'I', '2019', 'Pickup']
# ['Vincent', 'Baker', '21', 'Male', 'Toyota', 'Land Cruiser', '2015', 'SUV']
# ['Dawn', 'Smith', '67', 'Female', 'Dodge', 'Discovery Sport', '2020', 'Pickup']
# ['Keith', 'Ward', '50', 'Male', 'Dodge', 'Frontier Crew Cab', '2003', 'SUV']
# ['Marion', 'Jones', '49', 'Female', 'GMC', 'Lumina', '2003', 'Pickup']
# ['Mandy', 'Warner', '23', 'Female', 'Hyundai', 'Mirage', '1998', 'Pickup']
# ['Mohamed', 'Wright', '35', 'Male', 'Honda', 'Tacoma Double Cab', '2006', 'Sedan']
# ['Ross', 'Thompson', '73', 'Male', 'Toyota', 'Land Cruiser', '2013', 'Van/Minivan']
# ['David', 'Shepherd', '65', 'Male', 'Cadillac', 'Sierra 3500 HD Crew Cab', '2006', 'SUV']
# ['Joshua', 'Cox', '78', 'Male', 'HUMMER', 'Passport', '2015', 'Sedan, Coupe']
# ['Sally', 'Atkinson', '84', 'Female', 'Mercedes-Benz', 'Accord', '2000', 'SUV']
# ['Lisa', 'Matthews', '67', 'Female', 'Suzuki', 'Nubira', '2019', 'Van/Minivan']
# ['Harry', 'Kelly', '81', 'Male', 'Isuzu', 'Boxster', '1994', 'Pickup']
# ['Gillian', 'Holden', '55', 'Female', 'Toyota', '57', '2012', 'Wagon']
# ['Joseph', 'Harding', '50', 'Male', 'Ford', 'Equinox', '2016', 'Coupe, Sedan, Convertible']
# ['David', 'Pollard', '61', 'Male', 'GMC', 'GT-R', '1997', 'Coupe']
# ['Frances', 'Miah', '88', 'Female', 'Toyota', 'Previa', '2015', 'Convertible, Hatchback']
# ['Ann', 'Murray', '30', 'Female', 'Chevrolet', 'NV1500 Cargo', '2006', 'SUV']
# ['Kelly', 'Collins', '32', 'Female', 'Ford', 'NV3500 HD Cargo', '2007', 'SUV']
# ['Jane', 'Charlton', '90', 'Female', 'GMC', '850', '2019', 'Sedan, Wagon']
# ['Joshua', 'Harris', '74', 'Male', 'Lotus', 'Sorento', '2009', 'Sedan']
# ['Rosie', 'Chadwick', '41', 'Female', 'Ford', 'Cayman', '2020', 'SUV']
# ['Marc', 'Davies', '31', 'Male', 'smart', 'Silverado 2500 HD Crew Cab', '1996', 'SUV']
# ['Damien', 'McCarthy', '81', 'Male', 'Subaru', 'Loyale', '1997', 'Sedan']
# ['Joyce', 'Mellor', '30', 'Female', 'Subaru', 'Express 2500 Passenger', '1997', 'Hatchback']
# ['Rita', 'Howard', '64', 'Female', 'Acura', 'Yukon', '2018', 'Sedan']
# ['Mark', 'Young', '59', 'Male', 'Chevrolet', '1500 Extended Cab', '2019', 'Convertible']
# ['Daniel', 'Potter', '41', 'Male', 'Honda', 'SL-Class', '1995', 'Pickup']
# ['Hazel', 'Foster', '67', 'Female', 'Honda', 'Expedition', '2018', 'Van/Minivan']
# ['Abigail', 'Doyle', '63', 'Female', 'Alfa Romeo', 'Cayenne', '1996', 'Van/Minivan']
# ['Ashley', 'Robinson', '31', 'Male', 'Audi', 'GL-Class', '2004', 'Sedan']
# ['Bethany', 'Barnett', '20', 'Female', 'Chevrolet', '1500 Classic Regular Cab', '2006', 'Van/Minivan']
# ['Josh', 'Harrison', '40', 'Male', 'Bentley', '370Z', '2011', 'SUV']
# ['Kathleen', 'Haynes', '87', 'Female', 'Honda', 'S5', '2006', 'Pickup']
# ['Albert', 'Andrews', '26', 'Male', 'Buick', 'Ram Wagon 3500', '2013', 'SUV']
# ['Nicola', 'Warner', '90', 'Female', 'Chevrolet', 'F150 Super Cab', '2016', 'Pickup']
# ['Max', 'Fraser', '31', 'Male', 'Dodge', 'LeSabre', '2000', 'Coupe']
# ['Marian', 'Sharpe', '49', 'Female', 'Ford', '500e', '2004', 'SUV']
# ['Samuel', 'Hamilton', '36', 'Male', 'Saab', 'Expedition', '2018', 'Coupe, Convertible']
# ['Jean', 'Mason', '30', 'Female', 'GMC', 'GX', '2016', 'Pickup']
# ['Julia', 'Fry', '83', 'Female', 'Honda', 'Silverado 1500 LD Double Cab', '2014', 'Pickup']
# ['Allan', 'Jordan', '36', 'Male', 'Isuzu', '5 Series', '2009', 'Van/Minivan']
# ['Marc', 'Jones', '62', 'Male', 'Mitsubishi', '911', '2001', 'Sedan, Wagon']
# ['Kirsty', 'Lynch', '64', 'Female', 'Kia', '911', '1998', 'Pickup']
# ['Louise', 'Wilson', '65', 'Female', 'INFINITI', 'Safari Cargo', '2019', 'Sedan, Convertible']
# ['Sian', 'Thomas', '29', 'Female', 'BMW', 'Econoline E350 Cargo', '1999', 'Sedan, Wagon']
# ['Stacey', 'Turner', '19', 'Female', 'GMC', 'Suburban 1500', '1992', 'Sedan, Coupe']
# ['Georgia', 'Williams', '45', 'Female', 'Ford', 'Monte Carlo', '2010', 'Sedan, Coupe']
# ['Catherine', 'Jones', '38', 'Female', 'GMC', '7 Series', '2002', 'Sedan']
# ['Stacey', 'Donnelly', '65', 'Female', 'Acura', 'Cayman', '2018', 'Sedan']
# ['Gerald', 'Young', '88', 'Male', 'Chevrolet', 'Golf', '2004', 'Van/Minivan']
# ['Charlie', 'Clarke', '57', 'Male', 'Chevrolet', 'Malibu', '2006', 'Hatchback']
# ['Geraldine', 'Martin', '57', 'Female', 'Pontiac', 'M3', '2013', 'Convertible, Coupe']
# ['Ian', 'Holland', '40', 'Male', 'Mercedes-Benz', 'Prius', '1997', 'Coupe']
# ['Brian', 'Thompson', '36', 'Male', 'Chevrolet', 'Rio', '2003', 'Coupe']
# ['Janice', 'Newman', '25', 'Female', 'Nissan', 'Ram Wagon 3500', '2000', 'SUV']
# ['Lynn', 'Thomas', '34', 'Female', 'Ford', 'Echo', '2011', 'Wagon']
# ['Donna', 'Smith', '67', 'Female', 'Nissan', 'Silverado 3500 Crew Cab', '2008', 'Pickup']
# ['Kerry', 'Smith', '54', 'Female', 'Nissan', 'Maxima', '2019', 'Pickup']
# ['Frank', 'Spencer', '31', 'Male', 'Hyundai', 'NV3500 HD Cargo', '2019', 'Sedan']
# ['Maurice', 'Richardson', '40', 'Male', 'Jaguar', 'Ram 3500 Regular Cab', '1993', 'Van/Minivan']
# ['Benjamin', 'Watson', '76', 'Male', 'Lexus', 'C-MAX Hybrid', '2014', 'SUV']
# ['Lorraine', 'Gray', '23', 'Female', 'Mitsubishi', 'Santa Fe', '2004', 'Van/Minivan']
# ['David', 'Burns', '65', 'Male', 'Kia', 'Rabbit', '1998', 'Hatchback']
# ['Claire', 'Williams', '86', 'Female', 'Buick', 'Impreza', '2018', 'Sedan']
# ['Marie', 'Carpenter', '74', 'Female', 'Kia', 'LC', '2015', 'Sedan, Coupe, Wagon']
# ['Conor', 'Walker', '25', 'Male', 'Volvo', 'Corvette', '2010', 'Hatchback']
# ['Marion', 'Nicholls', '79', 'Female', 'Chrysler', 'Continental', '1993', 'Sedan']
# ['Glen', 'Brooks', '82', 'Male', 'Kia', 'F150 Super Cab', '2019', 'Van/Minivan']
# ['Lawrence', 'Baker', '64', 'Male', 'Lincoln', 'F150 Regular Cab', '2003', 'Hatchback']
# ['Natasha', 'Rees', '64', 'Female', 'Audi', 'Grand Prix', '2016', 'Convertible']
# ['Sean', 'Jones', '39', 'Male', 'BMW', 'Camry Hybrid', '2000', 'Pickup']
# ['Rita', 'Nicholson', '50', 'Female', 'Mercedes-Benz', 'Armada', '2004', 'Coupe']
# ['Emma', 'Williams', '37', 'Female', 'Dodge', 'LC', '1996', 'Sedan']
# ['Joanna', 'Brown', '33', 'Female', 'MAZDA', 'Rio', '2011', 'Convertible']
# ['Ryan', 'Brown', '37', 'Male', 'Nissan', 'Silverado 2500 HD Regular Cab', '2000', 'SUV']
# ['Patricia', 'Harrison', '53', 'Female', 'INFINITI', 'Mustang', '2003', 'Sedan']
# ['Sheila', 'Watson', '61', 'Female', 'Nissan', 'F250 Super Duty Super Cab', '1995', 'Van/Minivan']
# ['Graham', 'Roberts', '22', 'Male', 'Mercedes-Benz', '500e', '2002', 'Sedan, Hatchback']
# ['Roger', 'Lewis', '71', 'Male', 'Ford', 'Sequoia', '1996', 'Sedan, Wagon']
# ['Elaine', 'Harvey', '58', 'Female', 'Lincoln', 'B-Series Cab Plus', '2010', 'Sedan']
# ['Joyce', 'Burke', '32', 'Female', 'GMC', 'Z4 M', '2006', 'SUV']
# ['Lynn', 'Parsons', '39', 'Female', 'Porsche', 'Sequoia', '1994', 'SUV']
# ['Leslie', 'Williams', '63', 'Male', 'Honda', 'Golf', '1998', 'SUV']
# ['Jemma', 'Morris', '86', 'Female', 'GMC', 'GLA', '2017', 'Van/Minivan']
# ['Frances', 'Fitzgerald', '60', 'Female', 'Mercury', '350Z', '2010', 'SUV']
# ['Terry', 'Evans', '21', 'Male', 'Lotus', 'S10 Crew Cab', '2014', 'Convertible']
# ['Elliot', 'Dixon', '36', 'Male', 'Mercury', 'JUKE', '2003', 'Wagon, Sedan']
# ['Scott', 'Kent', '64', 'Male', 'Chevrolet', 'SKY', '1998', 'SUV']
# ['Bruce', 'Hamilton', '30', 'Male', 'Mitsubishi', 'RX', '2008', 'Pickup']
# ['Kayleigh', 'Bray', '81', 'Female', 'Jaguar', 'Tahoe', '2009', 'SUV']
# ['Lesley', 'Murphy', '43', 'Female', 'Freightliner', 'Colorado Crew Cab', '2018', 'Van/Minivan']
# ['Kieran', 'Cook', '80', 'Male', 'Ford', 'Ram 2500 Quad Cab', '1996', 'Pickup']
# ['Trevor', 'Howe', '77', 'Male', 'Rolls-Royce', 'Colorado Extended Cab', '1993', 'Sedan']
# ['Ben', 'Booth', '58', 'Male', 'Nissan', 'Soul', '2015', 'Pickup']
# ['Natasha', 'Poole', '32', 'Female', 'Plymouth', 'Avalanche', '2007', 'Coupe']
# ['Mitchell', 'Wilson', '53', 'Male', 'Volvo', 'Galant', '2009', 'Sedan']
# ['Anna', 'Brookes', '31', 'Female', 'Toyota', 'Suburban 1500', '2005', 'Coupe']
# ['Daniel', 'Henry', '62', 'Male', 'Ford', 'Escalade ESV', '2018', 'Sedan']
# ['Arthur', 'Farmer', '58', 'Male', 'Nissan', 'Xtra Cab', '2016', 'Coupe']
# ['Aaron', 'Smith', '90', 'Male', 'Chevrolet', 'Ram Wagon 1500', '2000', 'Hatchback']
# ['Jason', 'Butcher', '23', 'Male', 'Jaguar', 'S-Class', '2007', 'Coupe']
# ['Vincent', 'Bull', '42', 'Male', 'Hyundai', 'Safari Cargo', '2018', 'Sedan']
# ['Aimee', 'Hardy', '30', 'Female', 'Honda', 'Regal', '1999', 'Wagon, Sedan']
# ['Linda', 'Walker', '65', 'Female', 'Dodge', 'Sierra 3500 HD Crew Cab', '2012', 'Pickup']
# ['Stacey', 'Barnes', '25', 'Female', 'Ford', 'DeVille', '2007', 'Pickup']
# ['Charlotte', 'King', '75', 'Female', 'Jeep', 'Montero', '2012', 'Pickup']
# ['Kieran', "O'Connor", '38', 'Male', 'Nissan', 'Diamante', '2015', 'Sedan, Coupe']
# ['Philip', 'Scott', '87', 'Male', 'Chevrolet', 'S80', '2017', 'Pickup']
# ['Gareth', 'Knight', '70', 'Male', 'Lincoln', 'Accent', '1995', 'SUV']
# ['Shaun', 'Ford', '44', 'Male', 'Lincoln', 'MDX Sport Hybrid', '2000', 'Coupe']
# ['Tom', 'Brown', '53', 'Male', 'INFINITI', 'Savana 3500 Cargo', '1999', 'Sedan']
# ['Jenna', 'Ingram', '21', 'Female', 'Toyota', 'Liberty', '2005', 'Van/Minivan']
# ['Angela', 'Wall', '53', 'Female', 'Acura', 'LX', '1999', 'Pickup']
# ['Glenn', 'Rogers', '87', 'Male', 'Jeep', 'Sierra (Classic) 2500 HD Regular Cab', '2011', 'Coupe']
# ['Eric', 'Smith', '89', 'Male', 'Porsche', 'A3', '2017', 'SUV']
# ['Georgina', 'Thompson', '81', 'Female', 'Jaguar', 'Pilot', '2010', 'SUV']
# ['Kenneth', 'Robinson', '86', 'Male', 'Volkswagen', 'LaCrosse', '2015', 'SUV']
# ['David', "O'Sullivan", '75', 'Male', 'Ford', 'F350 Super Duty Super Cab', '2016', 'Coupe']
# ['Shannon', 'Barnett', '90', 'Female', 'Toyota', 'Vandura 3500', '1993', 'Coupe']
# ['Natalie', 'Thomas', '39', 'Female', 'Hyundai', 'GLS', '2009', 'Sedan, Wagon']
# ['Bradley', 'Hunt', '42', 'Male', 'Ford', 'Sonata', '2017', 'SUV']
# ['Clare', 'Carter', '76', 'Female', 'GMC', 'Paceman', '2018', 'Van/Minivan']
# ['Mohammed', 'Roberts', '26', 'Male', 'Lincoln', 'Civic Type R', '1998', 'Sedan']
# ['Liam', 'Edwards', '50', 'Male', 'Mitsubishi', 'Sable', '2011', 'Coupe']
# ['Jonathan', 'Austin', '30', 'Male', 'Volvo', 'Passat', '2002', 'Van/Minivan']
# ['Mary', 'Clayton', '28', 'Female', 'Ram', 'IS', '2006', 'Pickup']
# ['Amanda', 'Duncan', '33', 'Female', 'Chevrolet', 'Tacoma Regular Cab', '2019', 'Van/Minivan']
# ['Geraldine', 'Johnson', '27', 'Female', 'Dodge', 'Avenger', '2017', 'Pickup']
# ['Alexander', 'Reid', '27', 'Male', 'Nissan', 'Viper', '2018', 'SUV']
# ['Suzanne', 'Carter', '53', 'Female', 'BMW', 'Sonata', '2009', 'Sedan, Coupe']
# ['Dale', 'Jones', '24', 'Male', 'Volvo', 'Seville', '2007', 'SUV']
# ['Helen', 'Carr', '82', 'Female', 'Toyota', 'Corvette', '2013', 'SUV']
# ['Jacqueline', 'Booth', '74', 'Female', 'MINI', 'Expedition', '1995', 'Pickup']
# ['Jordan', 'Thompson', '82', 'Male', 'Lexus', 'Cougar', '1994', 'Sedan']
# ['Geoffrey', 'Jarvis', '20', 'Male', 'GMC', '500X', '1992', 'Coupe, Convertible']
# ['Donna', 'Summers', '66', 'Female', 'Chevrolet', 'Soul', '2000', 'Coupe']
# ['Suzanne', 'Hughes', '51', 'Female', 'Ford', 'RX', '2016', 'SUV']
# ['Abbie', 'Davis', '46', 'Female', 'Volvo', 'Vitara', '2002', 'Pickup']
# ['Dean', 'Ellis', '28', 'Male', 'Acura', 'tC', '2004', 'Convertible, Coupe']
# ['Maurice', 'Wilson', '79', 'Male', 'Jaguar', 'Mark LT', '2002', 'Pickup']
# ['Rosemary', 'May', '87', 'Female', 'Lexus', 'Sentra', '2020', 'Wagon']
# ['Yvonne', 'Thompson', '42', 'Female', 'Mercury', '6 Series', '2013', 'SUV']
# ['Craig', 'Thompson', '86', 'Male', 'Nissan', 'LaCrosse', '2015', 'Convertible, Sedan']
# ['Julian', 'Dixon', '87', 'Male', 'Hyundai', 'Avenger', '2018', 'Pickup']
# ['Megan', 'Woodward', '86', 'Female', 'Volkswagen', 'A8', '2011', 'Sedan']
# ['Angela', 'Briggs', '36', 'Female', 'Cadillac', 'Malibu', '2013', 'Sedan']
# ['Michael', 'Collins', '80', 'Male', 'Dodge', '4C', '2006', 'Sedan, Coupe']
# ['Cameron', 'Lewis', '33', 'Male', 'Audi', 'Mercedes-AMG S-Class', '1998', 'Convertible']
# ['Angela', 'Lewis', '78', 'Female', 'Ford', 'B-Series Cab Plus', '2012', 'Van/Minivan']
# ['Stuart', 'Wilson', '69', 'Male', 'Mercedes-Benz', 'SRX', '1999', 'SUV']
# ['Olivia', 'Allen', '74', 'Female', 'Kia', 'C-Class', '2019', 'Sedan']
# ['Darren', 'Lewis', '42', 'Male', 'Chevrolet', 'Bonneville', '2001', 'Convertible, Coupe']
# ['Gregory', 'Bennett', '51', 'Male', 'GMC', 'Bentayga', '2010', 'SUV']
# ['Ian', 'Cartwright', '85', 'Male', 'smart', 'Ram 2500 Club Cab', '1996', 'Coupe']
# ['Molly', 'Morgan', '41', 'Female', 'Chevrolet', 'Tucson', '1996', 'Wagon']
# ['Jason', 'Ford', '27', 'Male', 'GMC', 'Transit Connect Cargo', '1992', 'Pickup']
# ['Shane', 'Phillips', '84', 'Male', 'MAZDA', 'Terraza', '2014', 'Coupe']
# ['Terence', 'Sharpe', '65', 'Male', 'Chevrolet', '500c', '2008', 'Hatchback']
# ['Malcolm', 'Powell', '77', 'Male', 'Cadillac', 'Tracker', '2003', 'Sedan, Wagon']
# ['Damian', 'Thomas', '70', 'Male', 'Maserati', 'Rally Wagon 2500', '2019', 'Sedan']
# ['Lauren', 'Matthews', '65', 'Female', 'Acura', 'Alero', '2017', 'Sedan']
# ['Douglas', 'Bailey', '82', 'Male', 'Honda', 'F150 Super Cab', '2002', 'SUV']
# ['Sharon', "O'Brien", '60', 'Female', 'INFINITI', 'F350 Super Duty Crew Cab', '2002', 'Sedan']
# ['Abbie', 'Bull', '71', 'Female', 'GMC', 'A6', '2012', 'Coupe, Convertible']
# ['Marcus', 'Summers', '60', 'Male', 'GMC', 'Ram 1500 Quad Cab', '2016', 'Hatchback']
# ['Adam', 'Mistry', '73', 'Male', 'Audi', 'Grand Caravan Passenger', '2014', 'Sedan, Coupe']
# ['Lawrence', 'Evans', '23', 'Male', 'Toyota', 'Highlander', '2018', 'SUV']
# ['Samuel', 'Richardson', '79', 'Male', 'Ford', 'Breeze', '2014', 'Sedan, Wagon']
# ['Hilary', 'Williams', '50', 'Female', 'GMC', 'Accord', '1995', 'SUV']
# ['Melanie', 'Butler', '61', 'Female', 'Ram', 'Capri', '2002', 'Sedan']
# ['Samuel', "O'Connor", '66', 'Male', 'Nissan', 'Sierra 1500 Regular Cab', '1994', 'Van/Minivan']
# ['Rosemary', 'Elliott', '43', 'Female', 'Scion', 'Matrix', '1998', 'SUV']
# ['Rhys', 'Davies', '64', 'Male', 'Chevrolet', 'Compass', '2007', 'Pickup']
# ['Melissa', 'Ward', '89', 'Female', 'Dodge', 'Sierra 1500 Double Cab', '2005', 'Convertible, Coupe']
# ['Denise', 'Godfrey', '34', 'Female', 'Mercedes-Benz', 'Frontier Crew Cab', '2004', 'Sedan']
# ...
# ['Jennifer', 'Evans', '69', 'Female', 'Mitsubishi', 'Odyssey', '2017', 'Convertible']
# ['Callum', 'Quinn', '65', 'Male', 'Land Rover', 'Rapide S', '1997', 'Coupe, Convertible']
# ['Margaret', 'Hardy', '39', 'Female', 'Mercedes-Benz', 'Viper', '2001', 'Hatchback']
# ['Marcus', 'Gibson', '90', 'Male', 'GMC', 'Colorado Crew Cab', '2008', 'Van/Minivan']
# ['Stewart', 'Griffin', '42', 'Male', 'Dodge', 'TLX', '2019', 'SUV']
# ['Natalie', 'Stone', '65', 'Female', 'Oldsmobile', '5 Series', '2003', 'SUV']
# ['Jodie', 'Coleman', '34', 'Female', 'GMC', 'TL', '2006', 'Wagon']
# ['Natalie', 'Holloway', '50', 'Female', 'Oldsmobile', 'Mulsanne', '2015', 'SUV']
# ['Gavin', 'Kelly', '45', 'Male', 'Lexus', 'LR3', '2005', 'Sedan']
# ['Rhys', 'Marshall', '34', 'Male', 'Suzuki', 'Grand Caravan Passenger', '2017', 'SUV']
# ['Melanie', 'Walsh', '27', 'Female', 'Land Rover', 'Avalon', '2010', 'Sedan']
# ['Kyle', 'Walters', '64', 'Male', 'Nissan', 'E-Class', '2009', 'Sedan']
# ['Lesley', 'Dean', '69', 'Female', 'Ford', 'Ram 3500 Quad Cab', '2012', 'Pickup']
# ['Frank', 'Young', '55', 'Male', 'Lexus', 'Tempo', '2005', 'Sedan']
# ['Ian', 'Hopkins', '90', 'Male', 'BMW', 'Windstar Cargo', '2004', 'Sedan']
# ['Leslie', 'Gallagher', '56', 'Male', 'Audi', 'Navigator', '2020', 'Coupe, Convertible']
# ['Tracey', 'Lord', '29', 'Female', 'Ford', '3500 Crew Cab', '2015', 'Sedan']
# ['Mary', 'White', '71', 'Female', 'Nissan', 'XC60', '2016', 'Sedan, Coupe, Wagon']
# ['Glenn', 'Hussain', '59', 'Male', 'Isuzu', 'Stealth', '1994', 'Convertible']
# ['Derek', "O'Neill", '34', 'Male', 'Jeep', 'Windstar Passenger', '2011', 'Coupe']
# ['Eileen', 'Thompson', '39', 'Female', 'Honda', 'IS', '2006', 'Sedan']
# ['Judith', 'May', '73', 'Female', 'Toyota', 'F350 Super Duty Crew Cab', '1995', 'Pickup']
# ['Lesley', 'Edwards', '37', 'Female', 'Ford', 'G70', '1999', 'Coupe']
# ['Emily', 'Akhtar', '87', 'Female', 'Mercury', 'Z3', '2005', 'Hatchback']
# ['Teresa', 'White', '69', 'Female', 'Dodge', 'Silverado 2500 Regular Cab', '2013', 'Sedan']
# ['Leslie', 'Walker', '62', 'Male', 'Ford', 'Mercedes-AMG CLS', '2012', 'Pickup']
# ['Lauren', 'King', '65', 'Female', 'Cadillac', 'Tacoma Regular Cab', '1994', 'Sedan']
# ['Valerie', 'Barnes', '53', 'Female', 'BMW', 'Montero', '2013', 'Hatchback']
# ['Guy', 'Harvey', '31', 'Male', 'Saab', 'Range Rover Sport', '2007', 'Sedan']
# ['Jane', 'Lewis', '43', 'Female', 'Lexus', 'Niro Plug-in Hybrid', '2017', 'Sedan']
# ['Sheila', 'Mills', '84', 'Female', 'Mercedes-Benz', 'Cobalt', '2016', 'Van/Minivan']
# ['Kate', 'Jordan', '39', 'Female', 'MAZDA', 'S-Series', '2009', 'Pickup']
# ['Karl', 'Knowles', '81', 'Male', 'Jeep', 'Econoline E250 Cargo', '2002', 'Pickup']
# ['Jade', 'Collier', '35', 'Female', 'Jeep', 'C30', '2014', 'Convertible']
# ['Simon', 'Reid', '55', 'Male', 'Ford', 'XC40', '2001', 'SUV']
# ['Frank', 'Turner', '72', 'Male', 'Ferrari', 'Econoline E350 Cargo', '2004', 'Sedan']
# ['Charlotte', 'Black', '58', 'Female', 'Ferrari', 'F350 Super Duty Super Cab', '2016', 'Pickup']
# ['Ian', 'Baxter', '70', 'Male', 'Toyota', 'New Yorker', '2014', 'Van/Minivan']
# ['Molly', 'Richards', '59', 'Female', 'BMW', 'M3', '2020', 'SUV']
# ['Janice', 'Wilson', '23', 'Female', 'GMC', 'F250 Super Duty Super Cab', '2014', 'Sedan']
# ['Ben', 'Rogers', '23', 'Male', 'Volkswagen', 'Vanquish', '1993', 'Pickup']
# ['Annette', 'Bull', '31', 'Female', 'INFINITI', 'Metris WORKER Cargo', '1998', 'Sedan']
# ['Lynne', 'Davison', '66', 'Female', 'Volkswagen', 'Savana 3500 Cargo', '2019', 'Pickup']
# ['Caroline', 'Richards', '41', 'Female', 'Kia', 'Quest', '2007', 'Wagon']
# ['Luke', 'Middleton', '42', 'Male', 'Volvo', 'Explorer', '2009', 'Pickup']
# ['Jean', 'Smith', '81', 'Female', 'Kia', 'allroad', '2010', 'Sedan']
# ['Jamie', 'Mahmood', '63', 'Male', 'MAZDA', 'Fusion', '2014', 'SUV']
# ['Eric', 'Foster', '58', 'Male', 'Chevrolet', 'F150 Super Cab', '2000', 'Pickup']
# ['Jake', 'Potter', '74', 'Male', 'Ford', 'CL-Class', '2002', 'SUV']
# ['Carl', 'Wilkinson', '84', 'Male', 'INFINITI', 'Niro Plug-in Hybrid', '2013', 'Wagon']
# ['Chloe', 'Thompson', '52', 'Female', 'Mercury', 'Convertible', '1998', 'SUV']
# ['Megan', 'Hammond', '37', 'Female', 'GMC', 'Tahoe', '2002', 'Sedan, Coupe, Convertible']
# ['Molly', 'Bentley', '34', 'Female', 'Volvo', '2500 HD Extended Cab', '2017', 'Sedan']
# ['Jayne', 'Matthews', '51', 'Female', 'Oldsmobile', 'XC90', '1994', 'Convertible']
# ['Daniel', 'Allan', '83', 'Male', 'Ford', 'Concorde', '2007', 'Sedan, Coupe']
# ['Emily', 'Norris', '32', 'Female', 'Ram', 'I', '1997', 'Coupe']
# ['Paul', 'Ward', '67', 'Male', 'BMW', 'Colorado Extended Cab', '1992', 'Wagon']
# ['Maureen', 'Quinn', '88', 'Female', 'Mitsubishi', 'Sierra 2500 HD Regular Cab', '2013', 'Sedan']
# ['Stacey', 'Williams', '47', 'Female', 'Lexus', 'Ascent', '2007', 'SUV']
# ['Georgina', 'Fox', '68', 'Female', 'Acura', 'Range Rover Velar', '2002', 'Sedan']
# ['Lynn', 'Booth', '39', 'Female', 'Chevrolet', 'Cutlass', '1994', 'Sedan']
# ['Aaron', 'Turner', '82', 'Male', 'Volvo', 'Focus', '2002', 'Sedan']
# ['Martin', 'Coleman', '69', 'Male', 'Toyota', 'Ranger Super Cab', '2018', 'Hatchback, Convertible']
# ['Julia', 'Bailey', '24', 'Female', 'GMC', '7 Series', '1994', 'Sedan']
# ['Gerard', 'Cook', '46', 'Male', 'GMC', 'Prius c', '2019', 'Pickup']
# ['Patricia', 'Lawrence', '53', 'Female', 'Audi', 'Cayman', '2010', 'Sedan']
# ['Glenn', 'Webster', '20', 'Male', 'Honda', 'Clubman', '2004', 'Sedan, Coupe, Wagon']
# ['Amelia', 'Stone', '19', 'Female', 'Cadillac', 'Versa', '2005', 'Sedan, Hatchback']
# ['Teresa', 'Jones', '84', 'Female', 'Acura', 'LR2', '2010', 'Van/Minivan']
# ['Marc', 'Jennings', '26', 'Male', 'Cadillac', 'Mystique', '2004', 'Sedan']
# ['Joyce', 'Gibbs', '67', 'Female', 'Nissan', 'i-MiEV', '2000', 'SUV']
# ['Ellie', 'Taylor', '33', 'Female', 'Ford', 'MKX', '2013', 'Coupe, Convertible']
# ['Albert', 'Phillips', '49', 'Male', 'Dodge', 'F450 Super Duty Crew Cab', '1999', 'Wagon']
# ['Megan', 'Palmer', '21', 'Female', 'Ford', 'M3', '2017', 'Convertible']
# ['Deborah', 'Taylor', '58', 'Female', 'Ford', 'Wrangler', '2016', 'SUV']
# ['Amanda', 'Jones', '63', 'Female', 'Isuzu', 'Veloster', '2019', 'SUV']
# ['Stephanie', 'Williams', '52', 'Female', 'Pontiac', 'Sierra 1500 HD Crew Cab', '1994', 'Sedan']
# ['Elliot', 'Brooks', '41', 'Male', 'Chevrolet', 'TSX', '2001', 'SUV']
# ['Brandon', 'Smith', '64', 'Male', 'Ram', 'RSX', '1999', 'Sedan']
# ['Joanne', 'Campbell', '65', 'Female', 'Plymouth', 'Civic', '2008', 'Sedan']
# ['Martyn', 'Morgan', '49', 'Male', 'Mercedes-Benz', 'F12berlinetta', '2008', 'Hatchback']
# ['Beverley', 'Collier', '58', 'Female', 'Chevrolet', 'Dakota Regular Cab', '2016', 'Sedan']
# ['Megan', 'Fletcher', '28', 'Female', 'Isuzu', 'fortwo electric drive', '2016', 'Pickup']
# ['Claire', 'Howell', '34', 'Female', 'GMC', 'Paseo', '1995', 'Hatchback, Sedan']
# ['Hollie', 'Stanley', '74', 'Female', 'Ford', 'S40', '2012', 'Van/Minivan']
# ['Bethany', 'Robinson', '27', 'Female', 'Kia', 'Tacoma Access Cab', '2015', 'Van/Minivan']
# ['Lee', 'McDonald', '29', 'Male', 'Freightliner', 'Grand Vitara', '2015', 'Sedan, Hatchback']
# ['Pauline', 'Kelly', '79', 'Female', 'GMC', '86', '2009', 'Sedan']
# ['Howard', 'Khan', '52', 'Male', 'Chevrolet', 'Canyon Extended Cab', '1999', 'Hatchback, Convertible']
# ['Brenda', 'Riley', '65', 'Female', 'Chrysler', 'Outback', '2013', 'Sedan, Hatchback']
# ['Maureen', 'Barrett', '89', 'Female', 'Chevrolet', 'LS', '1994', 'SUV']
# ['Denise', 'Parkin', '25', 'Female', 'Chevrolet', 'A8', '2012', 'Sedan']
# ['Leonard', 'Norris', '52', 'Male', 'Jeep', 'Sebring', '1997', 'Sedan, Coupe']
# ['Amber', 'Randall', '60', 'Female', 'Saturn', 'Murano', '1999', 'Sedan']
# ['Holly', 'Franklin', '71', 'Female', 'BMW', 'VUE', '2005', 'Van/Minivan']
# ['James', 'Lamb', '66', 'Male', 'Ford', 'Grand Caravan Passenger', '2016', 'Sedan']
# ['Tony', 'Williams', '31', 'Male', 'Dodge', 'A8', '2010', 'Sedan']
# ['Beth', 'Carter', '45', 'Female', 'Cadillac', 'RX', '2002', 'Van/Minivan']
# ['Rebecca', 'Gregory', '32', 'Female', 'Chevrolet', '370Z', '1997', 'Van/Minivan']
# ['Kathryn', 'Sheppard', '88', 'Female', 'Mercedes-Benz', 'Silhouette', '2002', 'Wagon']
# ['Adam', 'Walker', '78', 'Male', 'Jaguar', 'Range Rover', '1998', 'Pickup']
# ['Olivia', 'Holden', '71', 'Female', 'Volvo', 'Accord Crosstour', '2006', 'Convertible']
# ['Dawn', 'Duffy', '81', 'Female', 'Volkswagen', 'Tracer', '2015', 'Hatchback, Convertible']
# ['Ellie', 'Green', '42', 'Female', 'Audi', 'XK', '2013', 'Van/Minivan']
# ['Kieran', 'Barry', '57', 'Male', 'Dodge', 'Sierra 3500 HD Regular Cab', '2002', 'Van/Minivan']
# ['Abigail', 'Wood', '57', 'Female', 'Dodge', 'Tiburon', '2002', 'Wagon, Sedan']
# ['Damian', 'Dean', '24', 'Male', 'Alfa Romeo', 'Corvette', '2004', 'SUV']
# ['Gary', 'Read', '49', 'Male', 'Jeep', 'Escape', '2010', 'Pickup']
# ['Chelsea', 'Sheppard', '70', 'Female', 'Ford', 'Yaris', '2017', 'Coupe, Convertible']
# ['Carl', 'Watson', '75', 'Male', 'Chevrolet', 'Charger', '2014', 'Pickup']
# ['William', 'Mellor', '51', 'Male', 'Ford', 'Express 3500 Passenger', '2017', 'Coupe, Sedan']
# ['Katie', 'Hughes', '40', 'Female', 'Nissan', 'Giulia', '2019', 'Sedan']
# ['Marian', 'Reeves', '91', 'Female', 'MAZDA', 'Wrangler', '2013', 'Convertible']
# ['Katy', 'Pugh', '26', 'Female', 'Mercedes-Benz', 'Mirai', '1996', 'Sedan, Coupe, Hatchback']
# ['Alison', 'Fletcher', '77', 'Female', 'Toyota', 'Mercedes-AMG GLE Coupe', '2008', 'Van/Minivan']
# ['Jayne', 'Allen', '55', 'Female', 'Lincoln', 'Suburban 1500', '2008', 'Sedan, Wagon']
# ['Robin', 'Roberts', '26', 'Male', 'Subaru', 'A4', '2011', 'SUV']
# ['Barry', 'Bevan', '28', 'Male', 'Ferrari', 'Navigator', '2005', 'Coupe']
# ['Ashleigh', 'Clark', '24', 'Female', 'Volkswagen', 'Mystique', '2012', 'SUV']
# ['Colin', 'Moore', '77', 'Male', 'Toyota', '300 SL', '2004', 'Sedan']
# ['Molly', 'Sims', '85', 'Female', 'Dodge', 'Protege', '2006', 'Sedan']
# ['Sharon', 'Shaw', '90', 'Female', 'Ford', 'Savana 2500 Cargo', '2017', 'Van/Minivan']
# ['Lynn', 'Wilkinson', '78', 'Female', 'Ford', 'Land Cruiser', '2007', 'Coupe']
# ['Harry', 'Hughes', '20', 'Male', 'GMC', 'A8', '2013', 'Van/Minivan']
# ['Marian', 'McCarthy', '84', 'Female', 'FIAT', 'Sonoma Crew Cab', '2010', 'Pickup']
# ['Guy', 'Summers', '42', 'Male', 'Lincoln', 'A4', '2018', 'Pickup']
# ['Melanie', 'Freeman', '84', 'Female', 'Mitsubishi', 'Niro Plug-in Hybrid', '2019', 'Coupe']
# ['Mary', 'Davidson', '42', 'Female', 'GMC', '2500 Extended Cab', '2010', 'SUV']
# ['Kerry', 'Martin', '73', 'Female', 'Chevrolet', 'Tahoe', '2019', 'Sedan']
# ['Adam', 'Parkin', '18', 'Male', 'Toyota', 'Vitara', '2014', 'SUV']
# ['Joanne', 'Hancock', '47', 'Female', 'Mercury', 'Diamante', '2007', 'Wagon']
# ['Malcolm', 'Andrews', '51', 'Male', 'Ford', 'Topaz', '2008', 'Sedan']
# ['Lisa', 'Shah', '26', 'Female', 'Nissan', 'Ranger Regular Cab', '1998', 'Coupe, Convertible']
# ['Stacey', 'King', '77', 'Female', 'Aston Martin', 'Silverado 2500 HD Extended Cab', '1997', 'Van/Minivan']
# ['Ronald', 'Jones', '42', 'Male', 'Jeep', 'Accord', '2018', 'Sedan, Wagon']
# ['Charles', 'Blake', '51', 'Male', 'Rolls-Royce', '3000GT', '2020', 'Sedan, Coupe']
# ['Rosie', 'Parkinson', '71', 'Female', 'Jaguar', '911', '2010', 'Sedan']
# ['Richard', 'Lyons', '43', 'Male', 'Aston Martin', 'Durango', '2000', 'SUV']
# ['Henry', 'Blackburn', '32', 'Male', 'Ford', 'IS F', '2019', 'Sedan']
# ['Debra', 'Newton', '56', 'Female', 'Suzuki', 'Storm', '2017', 'Pickup']
# ['Bradley', 'Smith', '47', 'Male', 'Isuzu', 'B-Series Regular Cab', '2017', 'SUV']
# ['Helen', 'Begum', '64', 'Female', 'Ford', 'XJ', '2015', 'SUV']
# ['Janet', 'Lee', '67', 'Female', 'Audi', 'LEAF', '2007', 'Pickup']
# ['Garry', 'Moore', '47', 'Male', 'Honda', 'MX-5 Miata', '2006', 'Van/Minivan']
# ['Judith', 'Page', '37', 'Female', 'Mercedes-Benz', 'CR-V', '2001', 'Van/Minivan']
# ['Glenn', 'Crawford', '77', 'Male', 'Subaru', 'RX', '2001', 'Hatchback']
# ['Rebecca', 'Metcalfe', '36', 'Female', 'Cadillac', 'S6', '2018', 'SUV']
# ['Anne', 'Morris', '40', 'Female', 'MINI', 'Voyager', '2018', 'Sedan, Wagon']
# ['Neil', 'Allen', '57', 'Male', 'Volkswagen', 'Veracruz', '2014', 'SUV']
# ['Jade', 'Edwards', '62', 'Female', 'Ford', 'Durango', '2010', 'Coupe']
# ['Damien', 'Walsh', '26', 'Male', 'Nissan', 'G80', '2001', 'SUV']
# ['Terence', 'Griffiths', '26', 'Male', 'Chrysler', 'Legend', '1999', 'Pickup']
# ['Harriet', 'Griffiths', '80', 'Female', 'Volkswagen', 'MKS', '2010', 'SUV']
# ['Jean', 'Lee', '23', 'Female', 'Mercedes-Benz', 'Vibe', '1992', 'Convertible']
# ['Lindsey', 'Hurst', '91', 'Female', 'Chrysler', 'Wrangler', '2006', 'SUV']
# ['Megan', 'Cameron', '48', 'Female', 'Toyota', 'iQ', '1996', 'Sedan']
# ['Ian', 'Greenwood', '28', 'Male', 'Hyundai', 'Silverado 2500 HD Crew Cab', '2018', 'SUV']
# ['Thomas', 'Harvey', '69', 'Male', 'Cadillac', 'SRX', '2003', 'Coupe, Convertible']
# ['Angela', 'Miller', '59', 'Female', 'MAZDA', 'LaCrosse', '1997', 'SUV']
# ['Fiona', 'Hill', '69', 'Female', 'Toyota', '3500 Regular Cab', '2003', 'SUV']
# ['Declan', 'Leonard', '54', 'Male', 'Lexus', 'Grand Am', '1994', 'Pickup']
# ['Kimberley', 'Smith', '39', 'Female', 'Ford', 'Cirrus', '2016', 'Pickup']
# ['Kimberley', 'Chambers', '23', 'Female', 'Plymouth', '2500 HD Club Coupe', '2017', 'Van/Minivan']
# ['Joanna', 'Kerr', '87', 'Female', 'GMC', 'Samurai', '1997', 'Coupe, Sedan']
# ['Lynda', 'Hewitt', '57', 'Female', 'Audi', '3500 Regular Cab', '1998', 'Coupe']
# ['Lee', 'Ford', '55', 'Male', 'Lincoln', 'BRZ', '2012', 'SUV']
# ['Conor', 'Johnson', '52', 'Male', 'Acura', 'Focus', '2017', 'Sedan, Hatchback']
# ['Sharon', 'Shaw', '23', 'Female', 'GMC', 'S5', '2003', 'Sedan, Convertible, Coupe']
# ['Geraldine', 'Hancock', '83', 'Female', 'Land Rover', 'Corolla', '2014', 'Van/Minivan']
# ['Christian', 'Collins', '30', 'Male', 'Ford', 'Tundra Regular Cab', '2014', 'SUV']
# ['Sean', 'White', '56', 'Male', 'Chevrolet', 'X5 M', '1996', 'Sedan, Coupe']
# ['Charlie', 'Gardner', '68', 'Male', 'Land Rover', 'MKX', '2015', 'Van/Minivan']
# ['Kenneth', 'Morgan', '50', 'Male', 'Mitsubishi', 'Explorer', '2000', 'Sedan']
# ['Valerie', 'Oliver', '66', 'Female', 'Nissan', 'Legacy', '2010', 'Coupe']
# ['Brandon', 'Hawkins', '74', 'Male', 'Honda', 'X-Type', '2017', 'Sedan, Wagon']
# ['Gail', 'Palmer', '77', 'Female', 'Lamborghini', 'Yukon XL 1500', '2016', 'Van/Minivan']
# ['Glenn', 'Lewis', '80', 'Male', 'Porsche', 'Colorado Crew Cab', '1998', 'Coupe']
# ['Frederick', 'Stevens', '73', 'Male', 'Dodge', 'Ram 1500 Quad Cab', '2010', 'Van/Minivan']
# ['Eleanor', 'Hartley', '42', 'Female', 'Chevrolet', 'CX-3', '2003', 'Sedan, Hatchback']
# ['Lesley', 'Harrison', '59', 'Female', 'FIAT', 'RL', '2007', 'Sedan']
# ['Denis', 'Clark', '69', 'Male', 'Dodge', '323', '2016', 'Wagon']
# ['Lindsey', 'Bibi', '79', 'Female', 'Nissan', 'Z8', '1998', 'Pickup']
# ['Mohamed', "O'Connor", '57', 'Male', 'BMW', 'QX', '2006', 'Van/Minivan']
# ['Lindsey', 'Ryan', '19', 'Female', 'Lexus', 'Ram 1500 Quad Cab', '2013', 'SUV']
# ['Kathryn', 'Whittaker', '57', 'Female', 'Audi', 'Savana 2500 Passenger', '2005', 'Van/Minivan']
# ['Terry', 'Clark', '39', 'Male', 'Freightliner', 'CL-Class', '2007', 'Convertible']
# ['Christian', 'Martin', '72', 'Male', 'Volvo', '3000GT', '1997', 'Pickup']
# ['Ian', 'Martin', '20', 'Male', 'Chevrolet', 'Mulsanne', '2016', 'Coupe']
# ['Ronald', 'Bennett', '27', 'Male', 'Ferrari', 'XJ', '2005', 'Sedan']
# ['Kyle', 'Sims', '72', 'Male', 'MAZDA', 'Tacoma Xtracab', '2007', 'SUV']
# ['Mohammad', 'Wilson', '19', 'Male', 'Mercedes-Benz', 'GLA-Class', '1999', 'Pickup']
# ['Jasmine', 'Bond', '25', 'Female', 'BMW', 'Rally Wagon 3500', '2018', 'Sedan']
# ['Nicole', 'Whitehead', '22', 'Female', 'Chevrolet', 'E250 Cargo', '2020', 'Sedan, Hatchback']
# ['Louis', 'Leonard', '37', 'Male', 'Hyundai', 'Silverado (Classic) 1500 HD Crew Cab', '2006', 'Van/Minivan']
# ['Shirley', 'Crawford', '60', 'Female', 'Kia', 'Phantom', '2001', 'Sedan']
# ['Patricia', 'Morris', '89', 'Female', 'Ford', 'RDX', '1998', 'SUV']
# ['Laura', 'Collins', '61', 'Female', 'Pontiac', 'Explorer Sport Trac', '2015', 'SUV']
# ['Diana', 'Barker', '35', 'Female', 'Acura', 'Yukon', '2005', 'Sedan, Wagon']
# ['Rosemary', 'Smith', '84', 'Female', 'Chevrolet', 'Impala', '2012', 'Pickup']
# ['Joe', 'Whitehead', '79', 'Male', 'Hyundai', 'Pilot', '2008', 'SUV']
# ['Ruth', 'Green', '73', 'Female', 'Ford', 'Transit 350 Wagon', '1998', 'SUV']

# %% [markdown]
# ## Step1: Converting the given xml file format to a csv file format

# %%
# Define the absolute path of the XML file
xml_dir = os.path.abspath('user_data_23_4.xml')

# Parse the XML file and get the root element
xml_tree = ET.parse(xml_dir)
xml_root = xml_tree.getroot()

# Create an empty list to store rows for CSV conversion
csv_rows = []

# Iterate through each 'user' element in the XML file
for user in xml_root.findall('user'):
    # Extract relevant attributes from each 'user' element and create a row
    row = [
        user.get('firstName'),
        user.get('lastName'),
        user.get('age'),
        user.get('sex'),
        user.get('retired'),
        user.get('dependants'),
        user.get('marital_status'),
        user.get('salary'),
        user.get('pension'),
        user.get('company'),
        user.get('commute_distance'),
        user.get('address_postcode'),
    ]
    # Append the row to the list of CSV rows
    csv_rows.append(row)

# Specify the path for the CSV file
csv_file_path = r'xml_to_csv.csv'

# Open the CSV file in write mode using a context manager
with open(csv_file_path, 'w', newline='') as csv_file:
    # Create a CSV writer object
    csv_writer = csv.writer(csv_file)
    
    # Write the header row to the CSV file
    csv_writer.writerow(['First Name', 'Second Name', 'Age (Years)', 'Sex', 'Retired', 'Dependants', 'Marital_status', 'Salary', 'Pension', 'Company', 'Commute_distance', 'Address_postcode'])
    
    # Write all rows to the CSV file
    csv_writer.writerows(csv_rows)

# Print a message indicating that the CSV file has been created
print(f'CSV file has been created: {csv_file_path}')
# Out:
# CSV file has been created: xml_to_csv.csv

# %% [markdown]
# ## Step2: Merging the new 'xml_to_csv.csv'  with the given 'user_data_23_4.csv' to make 'merged_output.csv' file

# %%
def merge_csv(file1_path, file2_path, common_columns, output_path):
    # Open the first CSV file and read its contents into a list of dictionaries
    with open(file1_path, 'r') as file1:
        reader1 = csv.DictReader(file1)
        data1 = list(reader1)

    # Open the second CSV file and read its contents into a list of dictionaries
    with open(file2_path, 'r') as file2:
        reader2 = csv.DictReader(file2)
        data2 = list(reader2)

    # Initialize an empty list to store merged data
    merged_data = []
    
    # Iterate through each row in the first CSV file
    for row1 in data1:
        # Iterate through each row in the second CSV file
        for row2 in data2:
            # Check if the values in specified common columns match for both rows
            if all(row1[col] == row2[col] for col in common_columns):
                # Merge the rows into a single dictionary
                merged_row = {**row1, **row2}
                # Append the merged row to the list of merged data
                merged_data.append(merged_row)

    # Get the fieldnames from the keys of the first merged row
    fieldnames = list(merged_data[0].keys())

    # Open the output CSV file in write mode using a context manager
    with open(output_path, 'w', newline='') as output_file:
        # Create a CSV DictWriter object
        writer = csv.DictWriter(output_file, fieldnames=fieldnames)
        # Write the header row to the output CSV file
        writer.writeheader()
        # Write all merged rows to the output CSV file
        writer.writerows(merged_data)

# Specify the paths and common columns for merging
file1_path = os.path.abspath('user_data_23_4.csv')
file2_path = os.path.abspath('xml_to_csv.csv')
common_columns = ['First Name', 'Second Name', 'Age (Years)', 'Sex']
output_path = 'merged_output.csv'

# Call the merge_csv function with specified parameters
merge_csv(file1_path, file2_path, common_columns, output_path)

# %% [markdown]
# ## Step3: Converting the given json file to a csv file format

# %%
# Define the absolute path of the JSON file
json_dir = os.path.abspath('user_data_23_4.json')

# Open the JSON file and load its contents into a Python data structure
with open(json_dir, 'r') as file:
    data = json.load(file)

# Get the fieldnames from the keys of the first dictionary in the JSON data
fieldnames = list(data[0].keys())

# Add a new field 'debt' to the list of fieldnames
fieldnames.append('debt')

# Specify the path for the output CSV file
output_csv_path = r'json_to_csv.csv'

# Open the output CSV file in write mode using a context manager
with open(output_csv_path, 'w', newline='') as output_file:
    # Create a CSV DictWriter object
    writer = csv.DictWriter(output_file, fieldnames=fieldnames)
    # Write the header row to the output CSV file
    writer.writeheader()
    # Write all rows from the JSON data to the output CSV file
    writer.writerows(data)

# Print a message indicating that the CSV file has been created
print(f'CSV file has been created: {os.path.abspath(output_csv_path)}')
# Out:
# CSV file has been created: c:\Users\Hp\Desktop\ASS\CETM50 ASS\json_to_csv.csv

# %% [markdown]
# ## step4: Transforming the debt column in the json_to_csv.csv file

# %%
json_to_csv_path = os.path.abspath('json_to_csv.csv')
# Open the CSV file for reading
with open(json_to_csv_path, 'r') as file:
    # Create a CSV reader
    reader = csv.DictReader(file)
    
    # Get the fieldnames from the original CSV
    fieldnames = reader.fieldnames

    # Modify the fieldnames (e.g., renaming the first three columns)
    fieldnames[0:3] = ('First Name', 'Second Name', 'Age (Years)')
    
    # Create a list to store modified rows
    modified_rows = []
    
    # Iterate over each row in the CSV
    for row in reader:
        # Get the 'debt' value from the current row
        debt_value = row['debt']
        
        # Check if 'debt' value is a JSON-like string
        if debt_value.startswith('{') and debt_value.endswith('}'):
            # Replace single quotes with double quotes
            debt_value = debt_value.replace("'", '"')

            try:
                # Parse the cleaned JSON-like string
                parsed_value = json.loads(debt_value)
                
                # Extract the 'amount' key from the parsed JSON
                amount = parsed_value.get('amount')
                
                # Replace the 'debt' value with the 'amount' value
                row['debt'] = amount
                
            except json.JSONDecodeError as e:
                # Handle JSON decoding error
                print(f"Error decoding JSON: {e}")
       
        # Add the modified row to the list
        modified_rows.append(row)

# Write the modified data to a new CSV file
with open('modified_json_to_csv.csv', 'w', newline='') as output_file:
    writer = csv.DictWriter(output_file, fieldnames=fieldnames)
    
    # Write the header
    writer.writeheader()
    
    # Write the modified rows
    writer.writerows(modified_rows)

# Print a message indicating the completion of the process
print(f"Modified data has been written to {os.path.abspath('modified_json_to_csv.csv')}")
# Out:
# Modified data has been written to c:\Users\Hp\Desktop\ASS\CETM50 ASS\modified_json_to_csv.csv

# %% [markdown]
# ## Step5: Merging the modified_json_to_csv.csv file and the merged_output.csv to have the final_merge.csv

# %%
# Specify the paths and common columns for merging
file1_path = os.path.abspath('merged_output.csv')
file2_path = os.path.abspath('modified_json_to_csv.csv')
common_columns = ['First Name', 'Second Name', 'Age (Years)']
output_path = 'final_merge.csv'

# Call the merge_csv function with specified parameters
merge_csv(file1_path, file2_path, common_columns, output_path)

print(f"The Final merged data has been written to {os.path.abspath('final_merge.csv')}")
# Out:
# The Final merged data has been written to c:\Users\Hp\Desktop\ASS\CETM50 ASS\final_merge.csv

# %% [markdown]
# ## Step6: Using PonyORM to map the final_merge.csv to a relational database

# %%
from pony.orm import Database, Required, Optional, PrimaryKey, db_session
import csv

# Define Pony ORM entities
db = Database()

class Person(db.Entity):
    id = PrimaryKey(int, auto=True)
    first_name = Required(str, column='First Name')
    second_name = Required(str, column='Second Name')
    age = Required(int, column='Age (Years)')
    sex = Required(str, column='Sex')
    vehicle_make = Required(str, column='Vehicle Make')
    vehicle_model = Required(str, column='Vehicle Model')
    vehicle_year = Required(int, column='Vehicle Year')
    vehicle_type = Required(str, column='Vehicle Type')
    retired = Required(bool, column='Retired')
    dependants = Required(int, column='Dependants')
    marital_status = Required(str, column='Marital_status')
    salary = Required(float, column='Salary')
    pension = Required(float, column='Pension')
    company = Required(str, column='Company')
    commute_distance = Required(float, column='Commute_distance')
    address_postcode = Required(str, column='Address_postcode')
    iban = Required(str, column='iban')
    credit_card_number = Required(str, column='credit_card_number')
    credit_card_security_code = Required(str, column='credit_card_security_code')
    credit_card_start_date = Required(str, column='credit_card_start_date')
    credit_card_end_date = Required(str, column='credit_card_end_date')
    address_main = Required(str, column='address_main')
    address_city = Required(str, column='address_city')
    debt = Optional(int, column='debt')

# Create a database connection
db.bind(provider='mysql', host='127.0.0.1', user='root', passwd='', db='practice_db')
db.generate_mapping(create_tables=True)

# Read the CSV file
csv_file_path = os.path.abspath('final_merge.csv')

# Insert data into the database
@db_session
def insert_csv_data():
    with open(csv_file_path, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            # Create a Person entity for each row in the CSV
            Person(
                first_name=row['First Name'],
                second_name=row['Second Name'],
                age=int(row['Age (Years)']) if row['Age (Years)'].isdigit() else 0,
                sex=row['Sex'],
                vehicle_make=row['Vehicle Make'],
                vehicle_model=row['Vehicle Model'],
                vehicle_year=int(row['Vehicle Year']) if row['Vehicle Year'].isdigit() else 0,
                vehicle_type=row['Vehicle Type'],
                retired=row['Retired'].lower() == 'true', 
                dependants=int(row['Dependants']) if row['Dependants'].isdigit() else 0,
                marital_status=row['Marital_status'],
                salary=float(row['Salary']) if row['Salary'].replace('.', '').isdigit() else 0.0,
                pension=float(row['Pension']) if row['Pension'].replace('.', '').isdigit() else 0.0,
                company=row['Company'],
                commute_distance=float(row['Commute_distance']) if row['Commute_distance'].replace('.', '').isdigit() else 0.0,
                address_postcode=row['Address_postcode'],
                iban=row['iban'],
                credit_card_number=row['credit_card_number'],
                credit_card_security_code=row['credit_card_security_code'],
                credit_card_start_date=row['credit_card_start_date'],
                credit_card_end_date=row['credit_card_end_date'],
                address_main=row['address_main'],
                address_city=row['address_city'],
                debt=int(row.get('debt')) if row.get('debt') and row.get('debt').isdigit() else 0 
            )

# Execute the data insertion
insert_csv_data()
print('Database created successfully')
# Out:
# Database created successfully
